# %% [markdown]
# # Assignment 1: Logistic Regression
# Welcome to week one of this specialization. You will learn about logistic regression. Concretely, you will be implementing logistic regression for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Learn how to extract features for logistic regression given some text
# * Implement logistic regression from scratch
# * Apply logistic regression on a natural language processing task
# * Test using your logistic regression
# * Perform error analysis
#
# We will be using a data set of tweets. Hopefully you will get more than 99% accuracy.
# Run the cell below to load in the packages.

# %% [markdown]
# ## Import functions and data

# %%
# run this cell to import nltk
import nltk
from os import getcwd

# %% [markdown]
# ### Imported functions
#
# Download the data needed for this assignment. Check out the [documentation for the twitter_samples dataset](http://www.nltk.org/howto/twitter.html).
#
# * twitter_samples: if you're running this notebook on your local computer, you will need to download it using:
# ```Python
# nltk.download('twitter_samples')
# ```
#
# * stopwords: if you're running this notebook on your local computer, you will need to download it using:
# ```python
# nltk.download('stopwords')
# ```
#
# #### Import some helper functions that we provided in the utils.py file:
# * `process_tweet()`: cleans the text, tokenizes it into separate words, removes stopwords, and converts words to stems.
# * `build_freqs()`: this counts how often a word in the 'corpus' (the entire set of tweets) was associated with a positive label '1' or a negative label '0', then builds the `freqs` dictionary, where each key is a (word,label) tuple, and the value is the count of its frequency within the corpus of tweets.

# %%
# add folder, tmp2, from our local workspace containing pre-downloaded corpora files to nltk's data path
# this enables importing of these files without downloading it again when we refresh our workspace

filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
import numpy as np
import pandas as pd
from nltk.corpus import twitter_samples 

from utils import process_tweet, build_freqs

# %% [markdown]
# ### Prepare the data
# * The `twitter_samples` contains subsets of 5,000 positive tweets, 5,000 negative tweets, and the full set of 10,000 tweets.
#     * If you used all three datasets, we would introduce duplicates of the positive tweets and negative tweets.
#     * You will select just the five thousand positive tweets and five thousand negative tweets.

# %%
# select the set of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %% [markdown]
# * Train test split: 20% will be in the test set, and 80% in the training set.

# %%
# split the data into two pieces, one for training and one for testing (validation set) 
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg 
test_x = test_pos + test_neg

# %% [markdown]
# * Create the numpy array of positive labels and negative labels.

# %%
# combine positive and negative labels
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis=0)
test_y = np.append(np.ones((len(test_pos), 1)), np.zeros((len(test_neg), 1)), axis=0)

# %%
# Print the shape train and test sets
print("train_y.shape = " + str(train_y.shape))
print("test_y.shape = " + str(test_y.shape))

# %% [markdown]
# * Create the frequency dictionary using the imported `build_freqs()` function.
#     * We highly recommend that you open `utils.py` and read the `build_freqs()` function to understand what it is doing.
#     * To view the file directory, go to the menu and click File->Open.
#
# ```Python
#     for y,tweet in zip(ys, tweets):
#         for word in process_tweet(tweet):
#             pair = (word, y)
#             if pair in freqs:
#                 freqs[pair] += 1
#             else:
#                 freqs[pair] = 1
# ```
# * Notice how the outer for loop goes through each tweet, and the inner for loop steps through each word in a tweet.
# * The `freqs` dictionary is the frequency dictionary that's being built.
# * The key is the tuple (word, label), such as ("happy",1) or ("happy",0).  The value stored for each key is the count of how many times the word "happy" was associated with a positive label, or how many times "happy" was associated with a negative label.

# %%
# create frequency dictionary
freqs = build_freqs(train_x, train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 11346

# %% [markdown]
# #### Expected output
# ```
# type(freqs) = <class 'dict'>
# len(freqs) = 11346
# ```

# %% [markdown]
# ### Process tweet
# The given function `process_tweet()` tokenizes the tweet into individual words, removes stop words and applies stemming.

# %%
# test the function below
print('This is an example of a positive tweet: \n', train_x[0])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[0]))
# Out:
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processed version of the tweet:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']

# %% [markdown]
# #### Expected output
# ```
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processes version:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ```

# %% [markdown]
# # Part 1: Logistic regression
#
#
# ### Part 1.1: Sigmoid
# You will learn to use logistic regression for text classification.
# * The sigmoid function is defined as:
#
# $$ h(z) = \frac{1}{1+\exp^{-z}} \tag{1}$$
#
# It maps the input 'z' to a value that ranges between 0 and 1, and so it can be treated as a probability.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='../tmp2/sigmoid_plot.jpg' alt="alternate text" width="width" height="height" style="width:300px;height:200px;" /> Figure 1 </div>

# %% [markdown]
# #### Instructions: Implement the sigmoid function
# * You will want this function to work if z is a scalar as well as if it is an array.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.exp.html" > numpy.exp </a> </li>
#
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def sigmoid(z): 
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # calculate the sigmoid of z
    h = 1 / (1 + np.exp(-z))
    ### END CODE HERE ###
    
    return h

# %%
# Testing your function 
if (sigmoid(0) == 0.5):
    print('SUCCESS!')
else:
    print('Oops!')

if (sigmoid(4.92) == 0.9927537604041685):
    print('CORRECT!')
else:
    print('Oops again!')
# Out:
# SUCCESS!
# CORRECT!

# %% [markdown]
# ### Logistic regression: regression and a sigmoid
#
# Logistic regression takes a regular linear regression, and applies a sigmoid to the output of the linear regression.
#
# Regression:
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# Note that the $\theta$ values are "weights". If you took the Deep Learning Specialization, we referred to the weights with the `w` vector.  In this course, we're using a different variable $\theta$ to refer to the weights.
#
# Logistic regression
# $$ h(z) = \frac{1}{1+\exp^{-z}}$$
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# We will refer to 'z' as the 'logits'.

# %% [markdown]
# ### Part 1.2 Cost function and Gradient
#
# The cost function used for logistic regression is the average of the log loss across all training examples:
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^m y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)}))\tag{5} $$
# * $m$ is the number of training examples
# * $y^{(i)}$ is the actual label of the i-th training example.
# * $h(z(\theta)^{(i)})$ is the model's prediction for the i-th training example.
#
# The loss function for a single training example is
# $$ Loss = -1 \times \left( y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) \right)$$
#
# * All the $h$ values are between 0 and 1, so the logs will be negative. That is the reason for the factor of -1 applied to the sum of the two loss terms.
# * Note that when the model predicts 1 ($h(z(\theta)) = 1$) and the label $y$ is also 1, the loss for that training example is 0.
# * Similarly, when the model predicts 0 ($h(z(\theta)) = 0$) and the actual label is also 0, the loss for that training example is 0.
# * However, when the model prediction is close to 1 ($h(z(\theta)) = 0.9999$) and the label is 0, the second term of the log loss becomes a large negative number, which is then multiplied by the overall factor of -1 to convert it to a positive loss value. $-1 \times (1 - 0) \times log(1 - 0.9999) \approx 9.2$ The closer the model prediction gets to 1, the larger the loss.

# %%
# verify that when the model predicts close to 1, but the actual label is 0, the loss is a large positive value
-1 * (1 - 0) * np.log(1 - 0.9999) # loss is about 9.2
# Out:
# 9.210340371976294

# %% [markdown]
# * Likewise, if the model predicts close to 0 ($h(z) = 0.0001$) but the actual label is 1, the first term in the loss function becomes a large number: $-1 \times log(0.0001) \approx 9.2$.  The closer the prediction is to zero, the larger the loss.

# %%
# verify that when the model predicts close to 0 but the actual label is 1, the loss is a large positive value
-1 * np.log(0.0001) # loss is about 9.2
# Out:
# 9.210340371976182

# %% [markdown]
# #### Update the weights
#
# To update your weight vector $\theta$, you will apply gradient descent to iteratively improve your model's predictions.
# The gradient of the cost function $J$ with respect to one of the weights $\theta_j$ is:
#
# $$\nabla_{\theta_j}J(\theta) = \frac{1}{m} \sum_{i=1}^m(h^{(i)}-y^{(i)})x_j \tag{5}$$
# * 'i' is the index across all 'm' training examples.
# * 'j' is the index of the weight $\theta_j$, so $x_j$ is the feature associated with weight $\theta_j$
#
# * To update the weight $\theta_j$, we adjust it by subtracting a fraction of the gradient determined by $\alpha$:
# $$\theta_j = \theta_j - \alpha \times \nabla_{\theta_j}J(\theta) $$
# * The learning rate $\alpha$ is a value that we choose to control how big a single update will be.

# %% [markdown]
# ## Instructions: Implement gradient descent function
# * The number of iterations `num_iters` is the number of times that you'll use the entire training set.
# * For each iteration, you'll calculate the cost function using all training examples (there are `m` training examples), and for all features.
# * Instead of updating a single weight $\theta_i$ at a time, we can update all the weights in the column vector:
# $$\mathbf{\theta} = \begin{pmatrix}
# \theta_0
# \\
# \theta_1
# \\
# \theta_2
# \\
# \vdots
# \\
# \theta_n
# \end{pmatrix}$$
# * $\mathbf{\theta}$ has dimensions (n+1, 1), where 'n' is the number of features, and there is one more element for the bias term $\theta_0$ (note that the corresponding feature value $\mathbf{x_0}$ is 1).
# * The 'logits', 'z', are calculated by multiplying the feature matrix 'x' with the weight vector 'theta'.  $z = \mathbf{x}\mathbf{\theta}$
#     * $\mathbf{x}$ has dimensions (m, n+1)
#     * $\mathbf{\theta}$: has dimensions (n+1, 1)
#     * $\mathbf{z}$: has dimensions (m, 1)
# * The prediction 'h', is calculated by applying the sigmoid to each element in 'z': $h(z) = sigmoid(z)$, and has dimensions (m,1).
# * The cost function $J$ is calculated by taking the dot product of the vectors 'y' and 'log(h)'.  Since both 'y' and 'h' are column vectors (m,1), transpose the vector to the left, so that matrix multiplication of a row vector with column vector performs the dot product.
# $$J = \frac{-1}{m} \times \left(\mathbf{y}^T \cdot log(\mathbf{h}) + \mathbf{(1-y)}^T \cdot log(\mathbf{1-h}) \right)$$
# * The update of theta is also vectorized.  Because the dimensions of $\mathbf{x}$ are (m, n+1), and both $\mathbf{h}$ and $\mathbf{y}$ are (m, 1), we need to transpose the $\mathbf{x}$ and place it on the left in order to perform matrix multiplication, which then yields the (n+1, 1) answer we need:
# $$\mathbf{\theta} = \mathbf{\theta} - \frac{\alpha}{m} \times \left( \mathbf{x}^T \cdot \left( \mathbf{h-y} \right) \right)$$

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>use np.dot for matrix multiplication.</li>
#     <li>To ensure that the fraction -1/m is a decimal value, cast either the numerator or denominator (or both), like `float(1)`, or write `1.` for the float version of 1. </li>
# </ul>
# </p>

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # get 'm', the number of rows in matrix x
    m = x.shape[0]
    
    for i in range(0, num_iters):
        
        # get z, the dot product of x and theta
        z = np.dot(x, theta)
        
        # get the sigmoid of z
        h = sigmoid(z)
        
        # calculate the cost function
        J = -(np.dot(y.T, np.log(h)) + np.dot((1 - y).T, np.log((1 - h)))) / m
        print("Cost after {} iteration = {}".format(i, J))

        # update the weights theta
        theta = theta - alpha * np.dot(x.T, (h - y)) / m
        
    ### END CODE HERE ###
    J = float(J)
    return J, theta

# %%
# Check the function
# Construct a synthetic test case using numpy PRNG functions
np.random.seed(1)
# X input is 10 x 3 with ones for the bias terms
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis=1)
# Y Labels are 10 x 1
tmp_Y = (np.random.rand(10, 1) > 0.35).astype(float)

# Apply gradient descent
tmp_J, tmp_theta = gradientDescent(tmp_X, tmp_Y, np.zeros((3, 1)), 1e-8, 700)
print(f"The cost after training is {tmp_J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(tmp_theta)]}")
# Out:
# Cost after 0 iteration = [[0.69314718]]
# Cost after 1 iteration = [[0.69305407]]
# Cost after 2 iteration = [[0.69296151]]
# Cost after 3 iteration = [[0.6928695]]
# Cost after 4 iteration = [[0.69277802]]
# Cost after 5 iteration = [[0.69268708]]
# Cost after 6 iteration = [[0.69259667]]
# Cost after 7 iteration = [[0.69250679]]
# Cost after 8 iteration = [[0.69241743]]
# Cost after 9 iteration = [[0.69232859]]
# Cost after 10 iteration = [[0.69224027]]
# Cost after 11 iteration = [[0.69215246]]
# Cost after 12 iteration = [[0.69206515]]
# Cost after 13 iteration = [[0.69197836]]
# Cost after 14 iteration = [[0.69189206]]
# Cost after 15 iteration = [[0.69180626]]
# Cost after 16 iteration = [[0.69172096]]
# Cost after 17 iteration = [[0.69163614]]
# Cost after 18 iteration = [[0.69155182]]
# Cost after 19 iteration = [[0.69146797]]
# Cost after 20 iteration = [[0.69138461]]
# Cost after 21 iteration = [[0.69130172]]
# Cost after 22 iteration = [[0.6912193]]
# Cost after 23 iteration = [[0.69113736]]
# Cost after 24 iteration = [[0.69105588]]
# Cost after 25 iteration = [[0.69097486]]
# Cost after 26 iteration = [[0.6908943]]
# Cost after 27 iteration = [[0.6908142]]
# Cost after 28 iteration = [[0.69073455]]
# Cost after 29 iteration = [[0.69065535]]
# Cost after 30 iteration = [[0.69057659]]
# Cost after 31 iteration = [[0.69049828]]
# Cost after 32 iteration = [[0.69042041]]
# Cost after 33 iteration = [[0.69034297]]
# Cost after 34 iteration = [[0.69026597]]
# Cost after 35 iteration = [[0.6901894]]
# Cost after 36 iteration = [[0.69011325]]
# Cost after 37 iteration = [[0.69003753]]
# Cost after 38 iteration = [[0.68996223]]
# Cost after 39 iteration = [[0.68988734]]
# Cost after 40 iteration = [[0.68981287]]
# Cost after 41 iteration = [[0.68973881]]
# Cost after 42 iteration = [[0.68966516]]
# Cost after 43 iteration = [[0.68959192]]
# Cost after 44 iteration = [[0.68951908]]
# Cost after 45 iteration = [[0.68944664]]
# Cost after 46 iteration = [[0.68937459]]
# Cost after 47 iteration = [[0.68930294]]
# Cost after 48 iteration = [[0.68923168]]
# Cost after 49 iteration = [[0.68916081]]
# Cost after 50 iteration = [[0.68909032]]
# Cost after 51 iteration = [[0.68902022]]
# Cost after 52 iteration = [[0.6889505]]
# Cost after 53 iteration = [[0.68888115]]
# Cost after 54 iteration = [[0.68881218]]
# Cost after 55 iteration = [[0.68874358]]
# Cost after 56 iteration = [[0.68867534]]
# Cost after 57 iteration = [[0.68860748]]
# Cost after 58 iteration = [[0.68853998]]
# Cost after 59 iteration = [[0.68847284]]
# Cost after 60 iteration = [[0.68840605]]
# Cost after 61 iteration = [[0.68833963]]
# Cost after 62 iteration = [[0.68827355]]
# Cost after 63 iteration = [[0.68820783]]
# Cost after 64 iteration = [[0.68814245]]
# Cost after 65 iteration = [[0.68807742]]
# Cost after 66 iteration = [[0.68801274]]
# Cost after 67 iteration = [[0.68794839]]
# Cost after 68 iteration = [[0.68788438]]
# Cost after 69 iteration = [[0.68782071]]
# Cost after 70 iteration = [[0.68775737]]
# Cost after 71 iteration = [[0.68769436]]
# Cost after 72 iteration = [[0.68763168]]
# Cost after 73 iteration = [[0.68756933]]
# Cost after 74 iteration = [[0.68750729]]
# Cost after 75 iteration = [[0.68744558]]
# Cost after 76 iteration = [[0.68738419]]
# Cost after 77 iteration = [[0.68732312]]
# Cost after 78 iteration = [[0.68726236]]
# Cost after 79 iteration = [[0.68720191]]
# Cost after 80 iteration = [[0.68714177]]
# Cost after 81 iteration = [[0.68708194]]
# Cost after 82 iteration = [[0.68702242]]
# Cost after 83 iteration = [[0.6869632]]
# Cost after 84 iteration = [[0.68690427]]
# Cost after 85 iteration = [[0.68684565]]
# Cost after 86 iteration = [[0.68678733]]
# Cost after 87 iteration = [[0.6867293]]
# Cost after 88 iteration = [[0.68667156]]
# Cost after 89 iteration = [[0.68661411]]
# Cost after 90 iteration = [[0.68655695]]
# Cost after 91 iteration = [[0.68650007]]
# Cost after 92 iteration = [[0.68644348]]
# Cost after 93 iteration = [[0.68638717]]
# Cost after 94 iteration = [[0.68633114]]
# Cost after 95 iteration = [[0.68627539]]
# Cost after 96 iteration = [[0.68621992]]
# Cost after 97 iteration = [[0.68616471]]
# Cost after 98 iteration = [[0.68610978]]
# Cost after 99 iteration = [[0.68605512]]
# Cost after 100 iteration = [[0.68600073]]
# Cost after 101 iteration = [[0.68594661]]
# Cost after 102 iteration = [[0.68589275]]
# Cost after 103 iteration = [[0.68583915]]
# Cost after 104 iteration = [[0.68578581]]
# Cost after 105 iteration = [[0.68573273]]
# Cost after 106 iteration = [[0.6856799]]
# Cost after 107 iteration = [[0.68562733]]
# Cost after 108 iteration = [[0.68557501]]
# Cost after 109 iteration = [[0.68552295]]
# Cost after 110 iteration = [[0.68547113]]
# Cost after 111 iteration = [[0.68541956]]
# Cost after 112 iteration = [[0.68536824]]
# Cost after 113 iteration = [[0.68531716]]
# Cost after 114 iteration = [[0.68526632]]
# Cost after 115 iteration = [[0.68521573]]
# Cost after 116 iteration = [[0.68516537]]
# Cost after 117 iteration = [[0.68511525]]
# Cost after 118 iteration = [[0.68506536]]
# Cost after 119 iteration = [[0.68501571]]
# Cost after 120 iteration = [[0.68496629]]
# Cost after 121 iteration = [[0.6849171]]
# Cost after 122 iteration = [[0.68486814]]
# Cost after 123 iteration = [[0.6848194]]
# Cost after 124 iteration = [[0.68477089]]
# Cost after 125 iteration = [[0.68472261]]
# Cost after 126 iteration = [[0.68467454]]
# Cost after 127 iteration = [[0.6846267]]
# Cost after 128 iteration = [[0.68457907]]
# Cost after 129 iteration = [[0.68453167]]
# Cost after 130 iteration = [[0.68448448]]
# Cost after 131 iteration = [[0.6844375]]
# Cost after 132 iteration = [[0.68439073]]
# Cost after 133 iteration = [[0.68434418]]
# Cost after 134 iteration = [[0.68429784]]
# Cost after 135 iteration = [[0.6842517]]
# Cost after 136 iteration = [[0.68420577]]
# Cost after 137 iteration = [[0.68416005]]
# Cost after 138 iteration = [[0.68411453]]
# Cost after 139 iteration = [[0.68406921]]
# Cost after 140 iteration = [[0.68402409]]
# Cost after 141 iteration = [[0.68397918]]
# Cost after 142 iteration = [[0.68393446]]
# Cost after 143 iteration = [[0.68388993]]
# Cost after 144 iteration = [[0.6838456]]
# Cost after 145 iteration = [[0.68380147]]
# Cost after 146 iteration = [[0.68375753]]
# Cost after 147 iteration = [[0.68371378]]
# Cost after 148 iteration = [[0.68367022]]
# Cost after 149 iteration = [[0.68362684]]
# Cost after 150 iteration = [[0.68358366]]
# Cost after 151 iteration = [[0.68354066]]
# Cost after 152 iteration = [[0.68349784]]
# Cost after 153 iteration = [[0.68345521]]
# Cost after 154 iteration = [[0.68341275]]
# Cost after 155 iteration = [[0.68337048]]
# Cost after 156 iteration = [[0.68332839]]
# Cost after 157 iteration = [[0.68328647]]
# Cost after 158 iteration = [[0.68324474]]
# Cost after 159 iteration = [[0.68320317]]
# Cost after 160 iteration = [[0.68316178]]
# Cost after 161 iteration = [[0.68312057]]
# Cost after 162 iteration = [[0.68307952]]
# Cost after 163 iteration = [[0.68303865]]
# Cost after 164 iteration = [[0.68299794]]
# Cost after 165 iteration = [[0.68295741]]
# Cost after 166 iteration = [[0.68291704]]
# Cost after 167 iteration = [[0.68287683]]
# Cost after 168 iteration = [[0.68283679]]
# Cost after 169 iteration = [[0.68279691]]
# Cost after 170 iteration = [[0.6827572]]
# Cost after 171 iteration = [[0.68271764]]
# Cost after 172 iteration = [[0.68267825]]
# Cost after 173 iteration = [[0.68263901]]
# Cost after 174 iteration = [[0.68259993]]
# Cost after 175 iteration = [[0.68256101]]
# Cost after 176 iteration = [[0.68252224]]
# Cost after 177 iteration = [[0.68248363]]
# Cost after 178 iteration = [[0.68244517]]
# Cost after 179 iteration = [[0.68240686]]
# Cost after 180 iteration = [[0.6823687]]
# Cost after 181 iteration = [[0.6823307]]
# Cost after 182 iteration = [[0.68229284]]
# Cost after 183 iteration = [[0.68225513]]
# Cost after 184 iteration = [[0.68221756]]
# Cost after 185 iteration = [[0.68218015]]
# Cost after 186 iteration = [[0.68214287]]
# Cost after 187 iteration = [[0.68210574]]
# Cost after 188 iteration = [[0.68206876]]
# Cost after 189 iteration = [[0.68203191]]
# Cost after 190 iteration = [[0.6819952]]
# Cost after 191 iteration = [[0.68195864]]
# Cost after 192 iteration = [[0.68192221]]
# Cost after 193 iteration = [[0.68188592]]
# Cost after 194 iteration = [[0.68184977]]
# Cost after 195 iteration = [[0.68181375]]
# Cost after 196 iteration = [[0.68177787]]
# Cost after 197 iteration = [[0.68174212]]
# Cost after 198 iteration = [[0.68170651]]
# Cost after 199 iteration = [[0.68167102]]
# Cost after 200 iteration = [[0.68163567]]
# Cost after 201 iteration = [[0.68160045]]
# Cost after 202 iteration = [[0.68156536]]
# Cost after 203 iteration = [[0.68153039]]
# Cost after 204 iteration = [[0.68149555]]
# Cost after 205 iteration = [[0.68146084]]
# Cost after 206 iteration = [[0.68142626]]
# Cost after 207 iteration = [[0.6813918]]
# Cost after 208 iteration = [[0.68135746]]
# Cost after 209 iteration = [[0.68132325]]
# Cost after 210 iteration = [[0.68128916]]
# Cost after 211 iteration = [[0.68125519]]
# Cost after 212 iteration = [[0.68122134]]
# Cost after 213 iteration = [[0.68118761]]
# Cost after 214 iteration = [[0.68115399]]
# Cost after 215 iteration = [[0.6811205]]
# Cost after 216 iteration = [[0.68108712]]
# Cost after 217 iteration = [[0.68105386]]
# Cost after 218 iteration = [[0.68102072]]
# Cost after 219 iteration = [[0.68098769]]
# Cost after 220 iteration = [[0.68095477]]
# Cost after 221 iteration = [[0.68092197]]
# Cost after 222 iteration = [[0.68088928]]
# Cost after 223 iteration = [[0.6808567]]
# Cost after 224 iteration = [[0.68082423]]
# Cost after 225 iteration = [[0.68079187]]
# Cost after 226 iteration = [[0.68075962]]
# Cost after 227 iteration = [[0.68072748]]
# Cost after 228 iteration = [[0.68069545]]
# Cost after 229 iteration = [[0.68066352]]
# Cost after 230 iteration = [[0.6806317]]
# Cost after 231 iteration = [[0.68059999]]
# Cost after 232 iteration = [[0.68056838]]
# Cost after 233 iteration = [[0.68053687]]
# Cost after 234 iteration = [[0.68050547]]
# Cost after 235 iteration = [[0.68047417]]
# Cost after 236 iteration = [[0.68044297]]
# Cost after 237 iteration = [[0.68041187]]
# Cost after 238 iteration = [[0.68038088]]
# Cost after 239 iteration = [[0.68034998]]
# Cost after 240 iteration = [[0.68031918]]
# Cost after 241 iteration = [[0.68028848]]
# Cost after 242 iteration = [[0.68025788]]
# Cost after 243 iteration = [[0.68022738]]
# Cost after 244 iteration = [[0.68019697]]
# Cost after 245 iteration = [[0.68016666]]
# Cost after 246 iteration = [[0.68013644]]
# Cost after 247 iteration = [[0.68010632]]
# Cost after 248 iteration = [[0.68007629]]
# Cost after 249 iteration = [[0.68004635]]
# Cost after 250 iteration = [[0.68001651]]
# Cost after 251 iteration = [[0.67998676]]
# Cost after 252 iteration = [[0.6799571]]
# Cost after 253 iteration = [[0.67992753]]
# Cost after 254 iteration = [[0.67989805]]
# Cost after 255 iteration = [[0.67986866]]
# Cost after 256 iteration = [[0.67983936]]
# Cost after 257 iteration = [[0.67981014]]
# Cost after 258 iteration = [[0.67978102]]
# Cost after 259 iteration = [[0.67975198]]
# Cost after 260 iteration = [[0.67972303]]
# Cost after 261 iteration = [[0.67969416]]
# Cost after 262 iteration = [[0.67966538]]
# Cost after 263 iteration = [[0.67963668]]
# Cost after 264 iteration = [[0.67960807]]
# Cost after 265 iteration = [[0.67957954]]
# Cost after 266 iteration = [[0.67955109]]
# Cost after 267 iteration = [[0.67952272]]
# Cost after 268 iteration = [[0.67949444]]
# Cost after 269 iteration = [[0.67946624]]
# Cost after 270 iteration = [[0.67943812]]
# Cost after 271 iteration = [[0.67941008]]
# Cost after 272 iteration = [[0.67938212]]
# Cost after 273 iteration = [[0.67935423]]
# Cost after 274 iteration = [[0.67932643]]
# Cost after 275 iteration = [[0.6792987]]
# Cost after 276 iteration = [[0.67927106]]
# Cost after 277 iteration = [[0.67924348]]
# Cost after 278 iteration = [[0.67921599]]
# Cost after 279 iteration = [[0.67918857]]
# Cost after 280 iteration = [[0.67916123]]
# Cost after 281 iteration = [[0.67913396]]
# Cost after 282 iteration = [[0.67910676]]
# Cost after 283 iteration = [[0.67907964]]
# Cost after 284 iteration = [[0.67905259]]
# Cost after 285 iteration = [[0.67902562]]
# Cost after 286 iteration = [[0.67899872]]
# Cost after 287 iteration = [[0.67897189]]
# Cost after 288 iteration = [[0.67894513]]
# Cost after 289 iteration = [[0.67891844]]
# Cost after 290 iteration = [[0.67889182]]
# Cost after 291 iteration = [[0.67886527]]
# Cost after 292 iteration = [[0.67883879]]
# Cost after 293 iteration = [[0.67881238]]
# Cost after 294 iteration = [[0.67878604]]
# Cost after 295 iteration = [[0.67875977]]
# Cost after 296 iteration = [[0.67873357]]
# Cost after 297 iteration = [[0.67870743]]
# Cost after 298 iteration = [[0.67868136]]
# Cost after 299 iteration = [[0.67865535]]
# Cost after 300 iteration = [[0.67862941]]
# Cost after 301 iteration = [[0.67860354]]
# Cost after 302 iteration = [[0.67857773]]
# Cost after 303 iteration = [[0.67855199]]
# Cost after 304 iteration = [[0.67852631]]
# Cost after 305 iteration = [[0.67850069]]
# Cost after 306 iteration = [[0.67847514]]
# Cost after 307 iteration = [[0.67844965]]
# Cost after 308 iteration = [[0.67842422]]
# Cost after 309 iteration = [[0.67839885]]
# Cost after 310 iteration = [[0.67837355]]
# Cost after 311 iteration = [[0.67834831]]
# Cost after 312 iteration = [[0.67832313]]
# Cost after 313 iteration = [[0.678298]]
# Cost after 314 iteration = [[0.67827294]]
# Cost after 315 iteration = [[0.67824794]]
# Cost after 316 iteration = [[0.678223]]
# Cost after 317 iteration = [[0.67819812]]
# Cost after 318 iteration = [[0.67817329]]
# Cost after 319 iteration = [[0.67814852]]
# Cost after 320 iteration = [[0.67812381]]
# Cost after 321 iteration = [[0.67809916]]
# Cost after 322 iteration = [[0.67807457]]
# Cost after 323 iteration = [[0.67805003]]
# Cost after 324 iteration = [[0.67802554]]
# Cost after 325 iteration = [[0.67800112]]
# Cost after 326 iteration = [[0.67797675]]
# Cost after 327 iteration = [[0.67795243]]
# Cost after 328 iteration = [[0.67792817]]
# Cost after 329 iteration = [[0.67790396]]
# Cost after 330 iteration = [[0.67787981]]
# Cost after 331 iteration = [[0.67785571]]
# Cost after 332 iteration = [[0.67783166]]
# Cost after 333 iteration = [[0.67780767]]
# Cost after 334 iteration = [[0.67778373]]
# Cost after 335 iteration = [[0.67775984]]
# Cost after 336 iteration = [[0.677736]]
# Cost after 337 iteration = [[0.67771222]]
# Cost after 338 iteration = [[0.67768848]]
# Cost after 339 iteration = [[0.6776648]]
# Cost after 340 iteration = [[0.67764117]]
# Cost after 341 iteration = [[0.67761759]]
# Cost after 342 iteration = [[0.67759406]]
# Cost after 343 iteration = [[0.67757058]]
# Cost after 344 iteration = [[0.67754714]]
# Cost after 345 iteration = [[0.67752376]]
# Cost after 346 iteration = [[0.67750042]]
# Cost after 347 iteration = [[0.67747714]]
# Cost after 348 iteration = [[0.6774539]]
# Cost after 349 iteration = [[0.67743071]]
# Cost after 350 iteration = [[0.67740756]]
# Cost after 351 iteration = [[0.67738447]]
# Cost after 352 iteration = [[0.67736142]]
# Cost after 353 iteration = [[0.67733842]]
# Cost after 354 iteration = [[0.67731546]]
# Cost after 355 iteration = [[0.67729255]]
# Cost after 356 iteration = [[0.67726968]]
# Cost after 357 iteration = [[0.67724686]]
# Cost after 358 iteration = [[0.67722409]]
# Cost after 359 iteration = [[0.67720136]]
# Cost after 360 iteration = [[0.67717868]]
# Cost after 361 iteration = [[0.67715603]]
# Cost after 362 iteration = [[0.67713344]]
# Cost after 363 iteration = [[0.67711088]]
# Cost after 364 iteration = [[0.67708837]]
# Cost after 365 iteration = [[0.67706591]]
# Cost after 366 iteration = [[0.67704348]]
# Cost after 367 iteration = [[0.6770211]]
# Cost after 368 iteration = [[0.67699876]]
# Cost after 369 iteration = [[0.67697647]]
# Cost after 370 iteration = [[0.67695421]]
# Cost after 371 iteration = [[0.676932]]
# Cost after 372 iteration = [[0.67690983]]
# Cost after 373 iteration = [[0.67688769]]
# Cost after 374 iteration = [[0.6768656]]
# Cost after 375 iteration = [[0.67684355]]
# Cost after 376 iteration = [[0.67682154]]
# Cost after 377 iteration = [[0.67679957]]
# Cost after 378 iteration = [[0.67677764]]
# Cost after 379 iteration = [[0.67675575]]
# Cost after 380 iteration = [[0.6767339]]
# Cost after 381 iteration = [[0.67671209]]
# Cost after 382 iteration = [[0.67669032]]
# Cost after 383 iteration = [[0.67666858]]
# Cost after 384 iteration = [[0.67664688]]
# Cost after 385 iteration = [[0.67662522]]
# Cost after 386 iteration = [[0.6766036]]
# Cost after 387 iteration = [[0.67658202]]
# Cost after 388 iteration = [[0.67656047]]
# Cost after 389 iteration = [[0.67653897]]
# Cost after 390 iteration = [[0.67651749]]
# Cost after 391 iteration = [[0.67649606]]
# Cost after 392 iteration = [[0.67647466]]
# Cost after 393 iteration = [[0.6764533]]
# Cost after 394 iteration = [[0.67643197]]
# Cost after 395 iteration = [[0.67641068]]
# Cost after 396 iteration = [[0.67638942]]
# Cost after 397 iteration = [[0.6763682]]
# Cost after 398 iteration = [[0.67634702]]
# Cost after 399 iteration = [[0.67632587]]
# Cost after 400 iteration = [[0.67630475]]
# Cost after 401 iteration = [[0.67628367]]
# Cost after 402 iteration = [[0.67626263]]
# Cost after 403 iteration = [[0.67624161]]
# Cost after 404 iteration = [[0.67622063]]
# Cost after 405 iteration = [[0.67619969]]
# Cost after 406 iteration = [[0.67617878]]
# Cost after 407 iteration = [[0.6761579]]
# Cost after 408 iteration = [[0.67613705]]
# Cost after 409 iteration = [[0.67611624]]
# Cost after 410 iteration = [[0.67609546]]
# Cost after 411 iteration = [[0.67607472]]
# Cost after 412 iteration = [[0.676054]]
# Cost after 413 iteration = [[0.67603332]]
# Cost after 414 iteration = [[0.67601267]]
# Cost after 415 iteration = [[0.67599205]]
# Cost after 416 iteration = [[0.67597146]]
# Cost after 417 iteration = [[0.6759509]]
# Cost after 418 iteration = [[0.67593038]]
# Cost after 419 iteration = [[0.67590988]]
# Cost after 420 iteration = [[0.67588942]]
# Cost after 421 iteration = [[0.67586899]]
# Cost after 422 iteration = [[0.67584858]]
# Cost after 423 iteration = [[0.67582821]]
# Cost after 424 iteration = [[0.67580787]]
# Cost after 425 iteration = [[0.67578756]]
# Cost after 426 iteration = [[0.67576727]]
# Cost after 427 iteration = [[0.67574702]]
# Cost after 428 iteration = [[0.6757268]]
# Cost after 429 iteration = [[0.6757066]]
# Cost after 430 iteration = [[0.67568643]]
# Cost after 431 iteration = [[0.6756663]]
# Cost after 432 iteration = [[0.67564619]]
# Cost after 433 iteration = [[0.67562611]]
# Cost after 434 iteration = [[0.67560606]]
# Cost after 435 iteration = [[0.67558603]]
# Cost after 436 iteration = [[0.67556604]]
# Cost after 437 iteration = [[0.67554607]]
# Cost after 438 iteration = [[0.67552613]]
# Cost after 439 iteration = [[0.67550622]]
# Cost after 440 iteration = [[0.67548633]]
# Cost after 441 iteration = [[0.67546648]]
# Cost after 442 iteration = [[0.67544665]]
# Cost after 443 iteration = [[0.67542684]]
# Cost after 444 iteration = [[0.67540707]]
# Cost after 445 iteration = [[0.67538731]]
# Cost after 446 iteration = [[0.67536759]]
# Cost after 447 iteration = [[0.67534789]]
# Cost after 448 iteration = [[0.67532822]]
# Cost after 449 iteration = [[0.67530858]]
# Cost after 450 iteration = [[0.67528896]]
# Cost after 451 iteration = [[0.67526936]]
# Cost after 452 iteration = [[0.67524979]]
# Cost after 453 iteration = [[0.67523025]]
# Cost after 454 iteration = [[0.67521073]]
# Cost after 455 iteration = [[0.67519124]]
# Cost after 456 iteration = [[0.67517177]]
# Cost after 457 iteration = [[0.67515233]]
# Cost after 458 iteration = [[0.67513291]]
# Cost after 459 iteration = [[0.67511352]]
# Cost after 460 iteration = [[0.67509415]]
# Cost after 461 iteration = [[0.6750748]]
# Cost after 462 iteration = [[0.67505548]]
# Cost after 463 iteration = [[0.67503618]]
# Cost after 464 iteration = [[0.67501691]]
# Cost after 465 iteration = [[0.67499766]]
# Cost after 466 iteration = [[0.67497844]]
# Cost after 467 iteration = [[0.67495923]]
# Cost after 468 iteration = [[0.67494005]]
# Cost after 469 iteration = [[0.6749209]]
# Cost after 470 iteration = [[0.67490177]]
# Cost after 471 iteration = [[0.67488266]]
# Cost after 472 iteration = [[0.67486357]]
# Cost after 473 iteration = [[0.67484451]]
# Cost after 474 iteration = [[0.67482546]]
# Cost after 475 iteration = [[0.67480645]]
# Cost after 476 iteration = [[0.67478745]]
# Cost after 477 iteration = [[0.67476848]]
# Cost after 478 iteration = [[0.67474952]]
# Cost after 479 iteration = [[0.67473059]]
# Cost after 480 iteration = [[0.67471168]]
# Cost after 481 iteration = [[0.6746928]]
# Cost after 482 iteration = [[0.67467393]]
# Cost after 483 iteration = [[0.67465509]]
# Cost after 484 iteration = [[0.67463627]]
# Cost after 485 iteration = [[0.67461747]]
# Cost after 486 iteration = [[0.67459869]]
# Cost after 487 iteration = [[0.67457993]]
# Cost after 488 iteration = [[0.67456119]]
# Cost after 489 iteration = [[0.67454247]]
# Cost after 490 iteration = [[0.67452378]]
# Cost after 491 iteration = [[0.6745051]]
# Cost after 492 iteration = [[0.67448645]]
# Cost after 493 iteration = [[0.67446781]]
# Cost after 494 iteration = [[0.6744492]]
# Cost after 495 iteration = [[0.6744306]]
# Cost after 496 iteration = [[0.67441203]]
# Cost after 497 iteration = [[0.67439348]]
# Cost after 498 iteration = [[0.67437494]]
# Cost after 499 iteration = [[0.67435643]]
# Cost after 500 iteration = [[0.67433793]]
# Cost after 501 iteration = [[0.67431946]]
# Cost after 502 iteration = [[0.674301]]
# Cost after 503 iteration = [[0.67428257]]
# Cost after 504 iteration = [[0.67426415]]
# Cost after 505 iteration = [[0.67424575]]
# Cost after 506 iteration = [[0.67422737]]
# Cost after 507 iteration = [[0.67420901]]
# Cost after 508 iteration = [[0.67419067]]
# Cost after 509 iteration = [[0.67417235]]
# Cost after 510 iteration = [[0.67415405]]
# Cost after 511 iteration = [[0.67413576]]
# Cost after 512 iteration = [[0.6741175]]
# Cost after 513 iteration = [[0.67409925]]
# Cost after 514 iteration = [[0.67408102]]
# Cost after 515 iteration = [[0.67406281]]
# Cost after 516 iteration = [[0.67404461]]
# Cost after 517 iteration = [[0.67402644]]
# Cost after 518 iteration = [[0.67400828]]
# Cost after 519 iteration = [[0.67399014]]
# Cost after 520 iteration = [[0.67397202]]
# Cost after 521 iteration = [[0.67395391]]
# Cost after 522 iteration = [[0.67393583]]
# Cost after 523 iteration = [[0.67391776]]
# Cost after 524 iteration = [[0.67389971]]
# Cost after 525 iteration = [[0.67388167]]
# Cost after 526 iteration = [[0.67386366]]
# Cost after 527 iteration = [[0.67384566]]
# Cost after 528 iteration = [[0.67382767]]
# Cost after 529 iteration = [[0.67380971]]
# Cost after 530 iteration = [[0.67379176]]
# Cost after 531 iteration = [[0.67377383]]
# Cost after 532 iteration = [[0.67375591]]
# Cost after 533 iteration = [[0.67373801]]
# Cost after 534 iteration = [[0.67372013]]
# Cost after 535 iteration = [[0.67370226]]
# Cost after 536 iteration = [[0.67368441]]
# Cost after 537 iteration = [[0.67366658]]
# Cost after 538 iteration = [[0.67364876]]
# Cost after 539 iteration = [[0.67363096]]
# Cost after 540 iteration = [[0.67361318]]
# Cost after 541 iteration = [[0.67359541]]
# Cost after 542 iteration = [[0.67357766]]
# Cost after 543 iteration = [[0.67355992]]
# Cost after 544 iteration = [[0.6735422]]
# Cost after 545 iteration = [[0.6735245]]
# Cost after 546 iteration = [[0.67350681]]
# Cost after 547 iteration = [[0.67348913]]
# Cost after 548 iteration = [[0.67347147]]
# Cost after 549 iteration = [[0.67345383]]
# Cost after 550 iteration = [[0.6734362]]
# Cost after 551 iteration = [[0.67341859]]
# Cost after 552 iteration = [[0.67340099]]
# Cost after 553 iteration = [[0.67338341]]
# Cost after 554 iteration = [[0.67336584]]
# Cost after 555 iteration = [[0.67334829]]
# Cost after 556 iteration = [[0.67333076]]
# Cost after 557 iteration = [[0.67331323]]
# Cost after 558 iteration = [[0.67329573]]
# Cost after 559 iteration = [[0.67327823]]
# Cost after 560 iteration = [[0.67326076]]
# Cost after 561 iteration = [[0.67324329]]
# Cost after 562 iteration = [[0.67322584]]
# Cost after 563 iteration = [[0.67320841]]
# Cost after 564 iteration = [[0.67319099]]
# Cost after 565 iteration = [[0.67317358]]
# Cost after 566 iteration = [[0.67315619]]
# Cost after 567 iteration = [[0.67313882]]
# Cost after 568 iteration = [[0.67312145]]
# Cost after 569 iteration = [[0.6731041]]
# Cost after 570 iteration = [[0.67308677]]
# Cost after 571 iteration = [[0.67306945]]
# Cost after 572 iteration = [[0.67305214]]
# Cost after 573 iteration = [[0.67303485]]
# Cost after 574 iteration = [[0.67301757]]
# Cost after 575 iteration = [[0.6730003]]
# Cost after 576 iteration = [[0.67298305]]
# Cost after 577 iteration = [[0.67296581]]
# Cost after 578 iteration = [[0.67294859]]
# Cost after 579 iteration = [[0.67293138]]
# Cost after 580 iteration = [[0.67291418]]
# Cost after 581 iteration = [[0.67289699]]
# Cost after 582 iteration = [[0.67287982]]
# Cost after 583 iteration = [[0.67286266]]
# Cost after 584 iteration = [[0.67284552]]
# Cost after 585 iteration = [[0.67282839]]
# Cost after 586 iteration = [[0.67281127]]
# Cost after 587 iteration = [[0.67279416]]
# Cost after 588 iteration = [[0.67277707]]
# Cost after 589 iteration = [[0.67275999]]
# Cost after 590 iteration = [[0.67274292]]
# Cost after 591 iteration = [[0.67272587]]
# Cost after 592 iteration = [[0.67270883]]
# Cost after 593 iteration = [[0.6726918]]
# Cost after 594 iteration = [[0.67267478]]
# Cost after 595 iteration = [[0.67265778]]
# Cost after 596 iteration = [[0.67264079]]
# Cost after 597 iteration = [[0.67262381]]
# Cost after 598 iteration = [[0.67260684]]
# Cost after 599 iteration = [[0.67258989]]
# Cost after 600 iteration = [[0.67257295]]
# Cost after 601 iteration = [[0.67255602]]
# Cost after 602 iteration = [[0.6725391]]
# Cost after 603 iteration = [[0.6725222]]
# Cost after 604 iteration = [[0.67250531]]
# Cost after 605 iteration = [[0.67248843]]
# Cost after 606 iteration = [[0.67247156]]
# Cost after 607 iteration = [[0.6724547]]
# Cost after 608 iteration = [[0.67243786]]
# Cost after 609 iteration = [[0.67242102]]
# Cost after 610 iteration = [[0.6724042]]
# Cost after 611 iteration = [[0.6723874]]
# Cost after 612 iteration = [[0.6723706]]
# Cost after 613 iteration = [[0.67235381]]
# Cost after 614 iteration = [[0.67233704]]
# Cost after 615 iteration = [[0.67232028]]
# Cost after 616 iteration = [[0.67230353]]
# Cost after 617 iteration = [[0.67228679]]
# Cost after 618 iteration = [[0.67227006]]
# Cost after 619 iteration = [[0.67225334]]
# Cost after 620 iteration = [[0.67223664]]
# Cost after 621 iteration = [[0.67221995]]
# Cost after 622 iteration = [[0.67220326]]
# Cost after 623 iteration = [[0.67218659]]
# Cost after 624 iteration = [[0.67216993]]
# Cost after 625 iteration = [[0.67215329]]
# Cost after 626 iteration = [[0.67213665]]
# Cost after 627 iteration = [[0.67212002]]
# Cost after 628 iteration = [[0.67210341]]
# Cost after 629 iteration = [[0.6720868]]
# Cost after 630 iteration = [[0.67207021]]
# Cost after 631 iteration = [[0.67205363]]
# Cost after 632 iteration = [[0.67203706]]
# Cost after 633 iteration = [[0.6720205]]
# Cost after 634 iteration = [[0.67200395]]
# Cost after 635 iteration = [[0.67198741]]
# Cost after 636 iteration = [[0.67197088]]
# Cost after 637 iteration = [[0.67195436]]
# Cost after 638 iteration = [[0.67193786]]
# Cost after 639 iteration = [[0.67192136]]
# Cost after 640 iteration = [[0.67190487]]
# Cost after 641 iteration = [[0.6718884]]
# Cost after 642 iteration = [[0.67187193]]
# Cost after 643 iteration = [[0.67185548]]
# Cost after 644 iteration = [[0.67183904]]
# Cost after 645 iteration = [[0.6718226]]
# Cost after 646 iteration = [[0.67180618]]
# Cost after 647 iteration = [[0.67178977]]
# Cost after 648 iteration = [[0.67177337]]
# Cost after 649 iteration = [[0.67175697]]
# Cost after 650 iteration = [[0.67174059]]
# Cost after 651 iteration = [[0.67172422]]
# Cost after 652 iteration = [[0.67170786]]
# Cost after 653 iteration = [[0.67169151]]
# Cost after 654 iteration = [[0.67167517]]
# Cost after 655 iteration = [[0.67165883]]
# Cost after 656 iteration = [[0.67164251]]
# Cost after 657 iteration = [[0.6716262]]
# Cost after 658 iteration = [[0.6716099]]
# Cost after 659 iteration = [[0.67159361]]
# Cost after 660 iteration = [[0.67157733]]
# Cost after 661 iteration = [[0.67156106]]
# Cost after 662 iteration = [[0.67154479]]
# Cost after 663 iteration = [[0.67152854]]
# Cost after 664 iteration = [[0.6715123]]
# Cost after 665 iteration = [[0.67149607]]
# Cost after 666 iteration = [[0.67147984]]
# Cost after 667 iteration = [[0.67146363]]
# Cost after 668 iteration = [[0.67144742]]
# Cost after 669 iteration = [[0.67143123]]
# Cost after 670 iteration = [[0.67141505]]
# Cost after 671 iteration = [[0.67139887]]
# Cost after 672 iteration = [[0.6713827]]
# Cost after 673 iteration = [[0.67136655]]
# Cost after 674 iteration = [[0.6713504]]
# Cost after 675 iteration = [[0.67133426]]
# Cost after 676 iteration = [[0.67131814]]
# Cost after 677 iteration = [[0.67130202]]
# Cost after 678 iteration = [[0.67128591]]
# Cost after 679 iteration = [[0.67126981]]
# Cost after 680 iteration = [[0.67125372]]
# Cost after 681 iteration = [[0.67123763]]
# Cost after 682 iteration = [[0.67122156]]
# Cost after 683 iteration = [[0.6712055]]
# Cost after 684 iteration = [[0.67118944]]
# Cost after 685 iteration = [[0.6711734]]
# Cost after 686 iteration = [[0.67115736]]
# Cost after 687 iteration = [[0.67114133]]
# Cost after 688 iteration = [[0.67112532]]
# Cost after 689 iteration = [[0.67110931]]
# Cost after 690 iteration = [[0.67109331]]
# Cost after 691 iteration = [[0.67107732]]
# Cost after 692 iteration = [[0.67106133]]
# Cost after 693 iteration = [[0.67104536]]
# Cost after 694 iteration = [[0.6710294]]
# Cost after 695 iteration = [[0.67101344]]
# Cost after 696 iteration = [[0.67099749]]
# Cost after 697 iteration = [[0.67098155]]
# Cost after 698 iteration = [[0.67096562]]
# Cost after 699 iteration = [[0.6709497]]
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]

# %% [markdown]
# #### Expected output
# ```
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]
# ```

# %% [markdown]
# ## Part 2: Extracting the features
#
# * Given a list of tweets, extract the features and store them in a matrix. You will extract two features.
#     * The first feature is the number of positive words in a tweet.
#     * The second feature is the number of negative words in a tweet.
# * Then train your logistic regression classifier on these features.
# * Test the classifier on a validation set.
#
# ### Instructions: Implement the extract_features function.
# * This function takes in a single tweet.
# * Process the tweet using the imported `process_tweet()` function and save the list of tweet words.
# * Loop through each word in the list of processed words
#     * For each word, check the `freqs` dictionary for the count when that word has a positive '1' label. (Check for the key (word, 1.0)
#     * Do the same for the count for when the word is associated with the negative label '0'. (Check for the key (word, 0.0).)

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Make sure you handle cases when the (word, label) key is not found in the dictionary. </li>
#     <li> Search the web for hints about using the `.get()` method of a Python dictionary.  Here is an <a href="https://www.programiz.com/python-programming/methods/dictionary/get" > example </a> </li>
# </ul>
# </p>

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def extract_features(tweet, freqs):
    '''
    Input: 
        tweet: a list of words for one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    word_l = process_tweet(tweet)
    
    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 3)) 
    
    #bias term is set to 1
    x[0,0] = 1 
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # loop through each word in the list of words
    for word in word_l:
        
        # increment the word count for the positive label 1
        x[0,1] += freqs.get((word, 1.0), 0)
        
        # increment the word count for the negative label 0
        x[0,2] += freqs.get((word, 0.0), 0)
        
    ### END CODE HERE ###
    assert(x.shape == (1, 3))
    return x

# %%
# Check your function

# test 1
# test on training data
tmp1 = extract_features(train_x[0], freqs)
print(tmp1)
# Out:
# [[1.00e+00 3.02e+03 6.10e+01]]

# %% [markdown]
# #### Expected output
# ```
# [[1.00e+00 3.02e+03 6.10e+01]]
# ```

# %%
# test 2:
# check for when the words are not in the freqs dictionary
tmp2 = extract_features('blorb bleeeeb bloooob', freqs)
print(tmp2)
# Out:
# [[1. 0. 0.]]

# %% [markdown]
# #### Expected output
# ```
# [[1. 0. 0.]]
# ```

# %% [markdown]
# ## Part 3: Training Your Model
#
# To train the model:
# * Stack the features for all training examples into a matrix `X`.
# * Call `gradientDescent`, which you've implemented above.
#
# This section is given to you.  Please read it for understanding and run the cell.

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)

# training labels corresponding to X
Y = train_y

# Apply gradient descent
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# Cost after 0 iteration = [[0.69314718]]
# Cost after 1 iteration = [[0.69207586]]
# Cost after 2 iteration = [[0.69100783]]
# Cost after 3 iteration = [[0.68994309]]
# Cost after 4 iteration = [[0.68888162]]
# Cost after 5 iteration = [[0.6878234]]
# Cost after 6 iteration = [[0.68676844]]
# Cost after 7 iteration = [[0.68571671]]
# Cost after 8 iteration = [[0.6846682]]
# Cost after 9 iteration = [[0.68362291]]
# Cost after 10 iteration = [[0.68258083]]
# Cost after 11 iteration = [[0.68154193]]
# Cost after 12 iteration = [[0.68050622]]
# Cost after 13 iteration = [[0.67947368]]
# Cost after 14 iteration = [[0.67844429]]
# Cost after 15 iteration = [[0.67741806]]
# Cost after 16 iteration = [[0.67639496]]
# Cost after 17 iteration = [[0.67537498]]
# Cost after 18 iteration = [[0.67435812]]
# Cost after 19 iteration = [[0.67334436]]
# Cost after 20 iteration = [[0.67233369]]
# Cost after 21 iteration = [[0.6713261]]
# Cost after 22 iteration = [[0.67032159]]
# Cost after 23 iteration = [[0.66932013]]
# Cost after 24 iteration = [[0.66832171]]
# Cost after 25 iteration = [[0.66732634]]
# Cost after 26 iteration = [[0.66633399]]
# Cost after 27 iteration = [[0.66534465]]
# Cost after 28 iteration = [[0.66435832]]
# Cost after 29 iteration = [[0.66337497]]
# Cost after 30 iteration = [[0.66239461]]
# Cost after 31 iteration = [[0.66141722]]
# Cost after 32 iteration = [[0.66044279]]
# Cost after 33 iteration = [[0.65947131]]
# Cost after 34 iteration = [[0.65850276]]
# Cost after 35 iteration = [[0.65753714]]
# Cost after 36 iteration = [[0.65657444]]
# Cost after 37 iteration = [[0.65561464]]
# Cost after 38 iteration = [[0.65465774]]
# Cost after 39 iteration = [[0.65370372]]
# Cost after 40 iteration = [[0.65275257]]
# Cost after 41 iteration = [[0.65180428]]
# Cost after 42 iteration = [[0.65085885]]
# Cost after 43 iteration = [[0.64991625]]
# Cost after 44 iteration = [[0.64897649]]
# Cost after 45 iteration = [[0.64803954]]
# Cost after 46 iteration = [[0.6471054]]
# Cost after 47 iteration = [[0.64617406]]
# Cost after 48 iteration = [[0.64524551]]
# Cost after 49 iteration = [[0.64431974]]
# Cost after 50 iteration = [[0.64339673]]
# Cost after 51 iteration = [[0.64247647]]
# Cost after 52 iteration = [[0.64155897]]
# Cost after 53 iteration = [[0.64064419]]
# Cost after 54 iteration = [[0.63973214]]
# Cost after 55 iteration = [[0.63882281]]
# Cost after 56 iteration = [[0.63791618]]
# Cost after 57 iteration = [[0.63701224]]
# Cost after 58 iteration = [[0.63611099]]
# Cost after 59 iteration = [[0.63521241]]
# Cost after 60 iteration = [[0.63431649]]
# Cost after 61 iteration = [[0.63342323]]
# Cost after 62 iteration = [[0.6325326]]
# Cost after 63 iteration = [[0.63164461]]
# Cost after 64 iteration = [[0.63075925]]
# Cost after 65 iteration = [[0.62987649]]
# Cost after 66 iteration = [[0.62899634]]
# Cost after 67 iteration = [[0.62811877]]
# Cost after 68 iteration = [[0.62724379]]
# Cost after 69 iteration = [[0.62637139]]
# Cost after 70 iteration = [[0.62550154]]
# Cost after 71 iteration = [[0.62463425]]
# Cost after 72 iteration = [[0.6237695]]
# Cost after 73 iteration = [[0.62290728]]
# Cost after 74 iteration = [[0.62204759]]
# Cost after 75 iteration = [[0.62119041]]
# Cost after 76 iteration = [[0.62033573]]
# Cost after 77 iteration = [[0.61948355]]
# Cost after 78 iteration = [[0.61863385]]
# Cost after 79 iteration = [[0.61778663]]
# Cost after 80 iteration = [[0.61694187]]
# Cost after 81 iteration = [[0.61609957]]
# Cost after 82 iteration = [[0.61525971]]
# Cost after 83 iteration = [[0.61442229]]
# Cost after 84 iteration = [[0.61358729]]
# Cost after 85 iteration = [[0.61275472]]
# Cost after 86 iteration = [[0.61192455]]
# Cost after 87 iteration = [[0.61109679]]
# Cost after 88 iteration = [[0.61027141]]
# Cost after 89 iteration = [[0.60944841]]
# Cost after 90 iteration = [[0.60862779]]
# Cost after 91 iteration = [[0.60780952]]
# Cost after 92 iteration = [[0.60699361]]
# Cost after 93 iteration = [[0.60618005]]
# Cost after 94 iteration = [[0.60536881]]
# Cost after 95 iteration = [[0.60455991]]
# Cost after 96 iteration = [[0.60375332]]
# Cost after 97 iteration = [[0.60294904]]
# Cost after 98 iteration = [[0.60214706]]
# Cost after 99 iteration = [[0.60134737]]
# Cost after 100 iteration = [[0.60054995]]
# Cost after 101 iteration = [[0.59975482]]
# Cost after 102 iteration = [[0.59896194]]
# Cost after 103 iteration = [[0.59817132]]
# Cost after 104 iteration = [[0.59738295]]
# Cost after 105 iteration = [[0.59659681]]
# Cost after 106 iteration = [[0.5958129]]
# Cost after 107 iteration = [[0.59503122]]
# Cost after 108 iteration = [[0.59425174]]
# Cost after 109 iteration = [[0.59347447]]
# Cost after 110 iteration = [[0.59269939]]
# Cost after 111 iteration = [[0.5919265]]
# Cost after 112 iteration = [[0.59115578]]
# Cost after 113 iteration = [[0.59038724]]
# Cost after 114 iteration = [[0.58962085]]
# Cost after 115 iteration = [[0.58885662]]
# Cost after 116 iteration = [[0.58809453]]
# Cost after 117 iteration = [[0.58733458]]
# Cost after 118 iteration = [[0.58657676]]
# Cost after 119 iteration = [[0.58582105]]
# Cost after 120 iteration = [[0.58506746]]
# Cost after 121 iteration = [[0.58431597]]
# Cost after 122 iteration = [[0.58356657]]
# Cost after 123 iteration = [[0.58281927]]
# Cost after 124 iteration = [[0.58207404]]
# Cost after 125 iteration = [[0.58133088]]
# Cost after 126 iteration = [[0.58058978]]
# Cost after 127 iteration = [[0.57985074]]
# Cost after 128 iteration = [[0.57911375]]
# Cost after 129 iteration = [[0.5783788]]
# Cost after 130 iteration = [[0.57764588]]
# Cost after 131 iteration = [[0.57691498]]
# Cost after 132 iteration = [[0.5761861]]
# Cost after 133 iteration = [[0.57545923]]
# Cost after 134 iteration = [[0.57473436]]
# Cost after 135 iteration = [[0.57401148]]
# Cost after 136 iteration = [[0.57329059]]
# Cost after 137 iteration = [[0.57257167]]
# Cost after 138 iteration = [[0.57185473]]
# Cost after 139 iteration = [[0.57113974]]
# Cost after 140 iteration = [[0.57042672]]
# Cost after 141 iteration = [[0.56971564]]
# Cost after 142 iteration = [[0.5690065]]
# Cost after 143 iteration = [[0.5682993]]
# Cost after 144 iteration = [[0.56759402]]
# Cost after 145 iteration = [[0.56689066]]
# Cost after 146 iteration = [[0.56618921]]
# Cost after 147 iteration = [[0.56548967]]
# Cost after 148 iteration = [[0.56479202]]
# Cost after 149 iteration = [[0.56409626]]
# Cost after 150 iteration = [[0.56340238]]
# Cost after 151 iteration = [[0.56271038]]
# Cost after 152 iteration = [[0.56202025]]
# Cost after 153 iteration = [[0.56133198]]
# Cost after 154 iteration = [[0.56064556]]
# Cost after 155 iteration = [[0.55996099]]
# Cost after 156 iteration = [[0.55927826]]
# Cost after 157 iteration = [[0.55859736]]
# Cost after 158 iteration = [[0.55791829]]
# Cost after 159 iteration = [[0.55724104]]
# Cost after 160 iteration = [[0.55656561]]
# Cost after 161 iteration = [[0.55589197]]
# Cost after 162 iteration = [[0.55522014]]
# Cost after 163 iteration = [[0.5545501]]
# Cost after 164 iteration = [[0.55388184]]
# Cost after 165 iteration = [[0.55321537]]
# Cost after 166 iteration = [[0.55255066]]
# Cost after 167 iteration = [[0.55188773]]
# Cost after 168 iteration = [[0.55122655]]
# Cost after 169 iteration = [[0.55056712]]
# Cost after 170 iteration = [[0.54990944]]
# Cost after 171 iteration = [[0.5492535]]
# Cost after 172 iteration = [[0.54859929]]
# Cost after 173 iteration = [[0.54794681]]
# Cost after 174 iteration = [[0.54729605]]
# Cost after 175 iteration = [[0.546647]]
# Cost after 176 iteration = [[0.54599966]]
# Cost after 177 iteration = [[0.54535402]]
# Cost after 178 iteration = [[0.54471007]]
# Cost after 179 iteration = [[0.54406782]]
# Cost after 180 iteration = [[0.54342724]]
# Cost after 181 iteration = [[0.54278835]]
# Cost after 182 iteration = [[0.54215112]]
# Cost after 183 iteration = [[0.54151555]]
# Cost after 184 iteration = [[0.54088164]]
# Cost after 185 iteration = [[0.54024939]]
# Cost after 186 iteration = [[0.53961878]]
# Cost after 187 iteration = [[0.53898981]]
# Cost after 188 iteration = [[0.53836247]]
# Cost after 189 iteration = [[0.53773676]]
# Cost after 190 iteration = [[0.53711267]]
# Cost after 191 iteration = [[0.53649019]]
# Cost after 192 iteration = [[0.53586933]]
# Cost after 193 iteration = [[0.53525007]]
# Cost after 194 iteration = [[0.5346324]]
# Cost after 195 iteration = [[0.53401633]]
# Cost after 196 iteration = [[0.53340185]]
# Cost after 197 iteration = [[0.53278894]]
# Cost after 198 iteration = [[0.53217761]]
# Cost after 199 iteration = [[0.53156785]]
# Cost after 200 iteration = [[0.53095965]]
# Cost after 201 iteration = [[0.530353]]
# Cost after 202 iteration = [[0.52974791]]
# Cost after 203 iteration = [[0.52914437]]
# Cost after 204 iteration = [[0.52854237]]
# Cost after 205 iteration = [[0.5279419]]
# Cost after 206 iteration = [[0.52734296]]
# Cost after 207 iteration = [[0.52674554]]
# Cost after 208 iteration = [[0.52614964]]
# Cost after 209 iteration = [[0.52555526]]
# Cost after 210 iteration = [[0.52496238]]
# Cost after 211 iteration = [[0.524371]]
# Cost after 212 iteration = [[0.52378112]]
# Cost after 213 iteration = [[0.52319274]]
# Cost after 214 iteration = [[0.52260583]]
# Cost after 215 iteration = [[0.52202041]]
# Cost after 216 iteration = [[0.52143647]]
# Cost after 217 iteration = [[0.52085399]]
# Cost after 218 iteration = [[0.52027298]]
# Cost after 219 iteration = [[0.51969342]]
# Cost after 220 iteration = [[0.51911533]]
# Cost after 221 iteration = [[0.51853868]]
# Cost after 222 iteration = [[0.51796347]]
# Cost after 223 iteration = [[0.5173897]]
# Cost after 224 iteration = [[0.51681737]]
# Cost after 225 iteration = [[0.51624646]]
# Cost after 226 iteration = [[0.51567698]]
# Cost after 227 iteration = [[0.51510892]]
# Cost after 228 iteration = [[0.51454227]]
# Cost after 229 iteration = [[0.51397702]]
# Cost after 230 iteration = [[0.51341318]]
# Cost after 231 iteration = [[0.51285074]]
# Cost after 232 iteration = [[0.5122897]]
# Cost after 233 iteration = [[0.51173004]]
# Cost after 234 iteration = [[0.51117176]]
# Cost after 235 iteration = [[0.51061486]]
# Cost after 236 iteration = [[0.51005934]]
# Cost after 237 iteration = [[0.50950519]]
# Cost after 238 iteration = [[0.5089524]]
# Cost after 239 iteration = [[0.50840097]]
# Cost after 240 iteration = [[0.50785089]]
# Cost after 241 iteration = [[0.50730217]]
# Cost after 242 iteration = [[0.50675478]]
# Cost after 243 iteration = [[0.50620874]]
# Cost after 244 iteration = [[0.50566404]]
# Cost after 245 iteration = [[0.50512067]]
# Cost after 246 iteration = [[0.50457862]]
# Cost after 247 iteration = [[0.50403789]]
# Cost after 248 iteration = [[0.50349848]]
# Cost after 249 iteration = [[0.50296039]]
# Cost after 250 iteration = [[0.5024236]]
# Cost after 251 iteration = [[0.50188812]]
# Cost after 252 iteration = [[0.50135393]]
# Cost after 253 iteration = [[0.50082104]]
# Cost after 254 iteration = [[0.50028944]]
# Cost after 255 iteration = [[0.49975913]]
# Cost after 256 iteration = [[0.49923009]]
# Cost after 257 iteration = [[0.49870233]]
# Cost after 258 iteration = [[0.49817585]]
# Cost after 259 iteration = [[0.49765063]]
# Cost after 260 iteration = [[0.49712668]]
# Cost after 261 iteration = [[0.49660398]]
# Cost after 262 iteration = [[0.49608254]]
# Cost after 263 iteration = [[0.49556236]]
# Cost after 264 iteration = [[0.49504341]]
# Cost after 265 iteration = [[0.49452571]]
# Cost after 266 iteration = [[0.49400925]]
# Cost after 267 iteration = [[0.49349402]]
# Cost after 268 iteration = [[0.49298002]]
# Cost after 269 iteration = [[0.49246724]]
# Cost after 270 iteration = [[0.49195569]]
# Cost after 271 iteration = [[0.49144535]]
# Cost after 272 iteration = [[0.49093623]]
# Cost after 273 iteration = [[0.49042831]]
# Cost after 274 iteration = [[0.4899216]]
# Cost after 275 iteration = [[0.48941609]]
# Cost after 276 iteration = [[0.48891177]]
# Cost after 277 iteration = [[0.48840865]]
# Cost after 278 iteration = [[0.48790671]]
# Cost after 279 iteration = [[0.48740596]]
# Cost after 280 iteration = [[0.48690639]]
# Cost after 281 iteration = [[0.486408]]
# Cost after 282 iteration = [[0.48591077]]
# Cost after 283 iteration = [[0.48541472]]
# Cost after 284 iteration = [[0.48491983]]
# Cost after 285 iteration = [[0.4844261]]
# Cost after 286 iteration = [[0.48393352]]
# Cost after 287 iteration = [[0.4834421]]
# Cost after 288 iteration = [[0.48295183]]
# Cost after 289 iteration = [[0.4824627]]
# Cost after 290 iteration = [[0.48197472]]
# Cost after 291 iteration = [[0.48148787]]
# Cost after 292 iteration = [[0.48100215]]
# Cost after 293 iteration = [[0.48051757]]
# Cost after 294 iteration = [[0.48003411]]
# Cost after 295 iteration = [[0.47955177]]
# Cost after 296 iteration = [[0.47907055]]
# Cost after 297 iteration = [[0.47859044]]
# Cost after 298 iteration = [[0.47811145]]
# Cost after 299 iteration = [[0.47763356]]
# Cost after 300 iteration = [[0.47715678]]
# Cost after 301 iteration = [[0.4766811]]
# Cost after 302 iteration = [[0.47620651]]
# Cost after 303 iteration = [[0.47573302]]
# Cost after 304 iteration = [[0.47526061]]
# Cost after 305 iteration = [[0.47478929]]
# Cost after 306 iteration = [[0.47431905]]
# Cost after 307 iteration = [[0.47384989]]
# Cost after 308 iteration = [[0.47338181]]
# Cost after 309 iteration = [[0.4729148]]
# Cost after 310 iteration = [[0.47244885]]
# Cost after 311 iteration = [[0.47198397]]
# Cost after 312 iteration = [[0.47152015]]
# Cost after 313 iteration = [[0.47105739]]
# Cost after 314 iteration = [[0.47059568]]
# Cost after 315 iteration = [[0.47013502]]
# Cost after 316 iteration = [[0.4696754]]
# Cost after 317 iteration = [[0.46921684]]
# Cost after 318 iteration = [[0.46875931]]
# Cost after 319 iteration = [[0.46830282]]
# Cost after 320 iteration = [[0.46784736]]
# Cost after 321 iteration = [[0.46739293]]
# Cost after 322 iteration = [[0.46693953]]
# Cost after 323 iteration = [[0.46648715]]
# Cost after 324 iteration = [[0.46603579]]
# Cost after 325 iteration = [[0.46558545]]
# Cost after 326 iteration = [[0.46513612]]
# Cost after 327 iteration = [[0.4646878]]
# Cost after 328 iteration = [[0.46424049]]
# Cost after 329 iteration = [[0.46379418]]
# Cost after 330 iteration = [[0.46334887]]
# Cost after 331 iteration = [[0.46290456]]
# Cost after 332 iteration = [[0.46246125]]
# Cost after 333 iteration = [[0.46201892]]
# Cost after 334 iteration = [[0.46157758]]
# Cost after 335 iteration = [[0.46113723]]
# Cost after 336 iteration = [[0.46069786]]
# Cost after 337 iteration = [[0.46025946]]
# Cost after 338 iteration = [[0.45982204]]
# Cost after 339 iteration = [[0.4593856]]
# Cost after 340 iteration = [[0.45895012]]
# Cost after 341 iteration = [[0.4585156]]
# Cost after 342 iteration = [[0.45808205]]
# Cost after 343 iteration = [[0.45764946]]
# Cost after 344 iteration = [[0.45721783]]
# Cost after 345 iteration = [[0.45678715]]
# Cost after 346 iteration = [[0.45635742]]
# Cost after 347 iteration = [[0.45592863]]
# Cost after 348 iteration = [[0.4555008]]
# Cost after 349 iteration = [[0.4550739]]
# Cost after 350 iteration = [[0.45464794]]
# Cost after 351 iteration = [[0.45422292]]
# Cost after 352 iteration = [[0.45379882]]
# Cost after 353 iteration = [[0.45337566]]
# Cost after 354 iteration = [[0.45295343]]
# Cost after 355 iteration = [[0.45253212]]
# Cost after 356 iteration = [[0.45211173]]
# Cost after 357 iteration = [[0.45169225]]
# Cost after 358 iteration = [[0.4512737]]
# Cost after 359 iteration = [[0.45085605]]
# Cost after 360 iteration = [[0.45043931]]
# Cost after 361 iteration = [[0.45002348]]
# Cost after 362 iteration = [[0.44960856]]
# Cost after 363 iteration = [[0.44919453]]
# Cost after 364 iteration = [[0.44878141]]
# Cost after 365 iteration = [[0.44836917]]
# Cost after 366 iteration = [[0.44795783]]
# Cost after 367 iteration = [[0.44754738]]
# Cost after 368 iteration = [[0.44713782]]
# Cost after 369 iteration = [[0.44672914]]
# Cost after 370 iteration = [[0.44632134]]
# Cost after 371 iteration = [[0.44591442]]
# Cost after 372 iteration = [[0.44550838]]
# Cost after 373 iteration = [[0.44510321]]
# Cost after 374 iteration = [[0.44469891]]
# Cost after 375 iteration = [[0.44429548]]
# Cost after 376 iteration = [[0.44389291]]
# Cost after 377 iteration = [[0.44349121]]
# Cost after 378 iteration = [[0.44309036]]
# Cost after 379 iteration = [[0.44269037]]
# Cost after 380 iteration = [[0.44229124]]
# Cost after 381 iteration = [[0.44189296]]
# Cost after 382 iteration = [[0.44149553]]
# Cost after 383 iteration = [[0.44109894]]
# Cost after 384 iteration = [[0.4407032]]
# Cost after 385 iteration = [[0.4403083]]
# Cost after 386 iteration = [[0.43991424]]
# Cost after 387 iteration = [[0.43952101]]
# Cost after 388 iteration = [[0.43912862]]
# Cost after 389 iteration = [[0.43873706]]
# Cost after 390 iteration = [[0.43834633]]
# Cost after 391 iteration = [[0.43795642]]
# Cost after 392 iteration = [[0.43756734]]
# Cost after 393 iteration = [[0.43717908]]
# Cost after 394 iteration = [[0.43679164]]
# Cost after 395 iteration = [[0.43640501]]
# Cost after 396 iteration = [[0.4360192]]
# Cost after 397 iteration = [[0.4356342]]
# Cost after 398 iteration = [[0.43525001]]
# Cost after 399 iteration = [[0.43486662]]
# Cost after 400 iteration = [[0.43448404]]
# Cost after 401 iteration = [[0.43410226]]
# Cost after 402 iteration = [[0.43372127]]
# Cost after 403 iteration = [[0.43334109]]
# Cost after 404 iteration = [[0.4329617]]
# Cost after 405 iteration = [[0.4325831]]
# Cost after 406 iteration = [[0.43220529]]
# Cost after 407 iteration = [[0.43182826]]
# Cost after 408 iteration = [[0.43145203]]
# Cost after 409 iteration = [[0.43107657]]
# Cost after 410 iteration = [[0.43070189]]
# Cost after 411 iteration = [[0.43032799]]
# Cost after 412 iteration = [[0.42995487]]
# Cost after 413 iteration = [[0.42958252]]
# Cost after 414 iteration = [[0.42921094]]
# Cost after 415 iteration = [[0.42884013]]
# Cost after 416 iteration = [[0.42847009]]
# Cost after 417 iteration = [[0.4281008]]
# Cost after 418 iteration = [[0.42773229]]
# Cost after 419 iteration = [[0.42736453]]
# Cost after 420 iteration = [[0.42699752]]
# Cost after 421 iteration = [[0.42663127]]
# Cost after 422 iteration = [[0.42626578]]
# Cost after 423 iteration = [[0.42590103]]
# Cost after 424 iteration = [[0.42553703]]
# Cost after 425 iteration = [[0.42517378]]
# Cost after 426 iteration = [[0.42481128]]
# Cost after 427 iteration = [[0.42444951]]
# Cost after 428 iteration = [[0.42408848]]
# Cost after 429 iteration = [[0.42372819]]
# Cost after 430 iteration = [[0.42336864]]
# Cost after 431 iteration = [[0.42300981]]
# Cost after 432 iteration = [[0.42265172]]
# Cost after 433 iteration = [[0.42229436]]
# Cost after 434 iteration = [[0.42193772]]
# Cost after 435 iteration = [[0.42158181]]
# Cost after 436 iteration = [[0.42122662]]
# Cost after 437 iteration = [[0.42087215]]
# Cost after 438 iteration = [[0.4205184]]
# Cost after 439 iteration = [[0.42016536]]
# Cost after 440 iteration = [[0.41981304]]
# Cost after 441 iteration = [[0.41946143]]
# Cost after 442 iteration = [[0.41911053]]
# Cost after 443 iteration = [[0.41876033]]
# Cost after 444 iteration = [[0.41841084]]
# Cost after 445 iteration = [[0.41806206]]
# Cost after 446 iteration = [[0.41771398]]
# Cost after 447 iteration = [[0.41736659]]
# Cost after 448 iteration = [[0.4170199]]
# Cost after 449 iteration = [[0.41667391]]
# Cost after 450 iteration = [[0.41632861]]
# Cost after 451 iteration = [[0.41598401]]
# Cost after 452 iteration = [[0.41564009]]
# Cost after 453 iteration = [[0.41529686]]
# Cost after 454 iteration = [[0.41495431]]
# Cost after 455 iteration = [[0.41461245]]
# Cost after 456 iteration = [[0.41427127]]
# Cost after 457 iteration = [[0.41393077]]
# Cost after 458 iteration = [[0.41359094]]
# Cost after 459 iteration = [[0.41325179]]
# Cost after 460 iteration = [[0.41291332]]
# Cost after 461 iteration = [[0.41257552]]
# Cost after 462 iteration = [[0.41223838]]
# Cost after 463 iteration = [[0.41190192]]
# Cost after 464 iteration = [[0.41156612]]
# Cost after 465 iteration = [[0.41123098]]
# Cost after 466 iteration = [[0.41089651]]
# Cost after 467 iteration = [[0.41056269]]
# Cost after 468 iteration = [[0.41022954]]
# Cost after 469 iteration = [[0.40989704]]
# Cost after 470 iteration = [[0.4095652]]
# Cost after 471 iteration = [[0.409234]]
# Cost after 472 iteration = [[0.40890346]]
# Cost after 473 iteration = [[0.40857357]]
# Cost after 474 iteration = [[0.40824433]]
# Cost after 475 iteration = [[0.40791573]]
# Cost after 476 iteration = [[0.40758777]]
# Cost after 477 iteration = [[0.40726046]]
# Cost after 478 iteration = [[0.40693379]]
# Cost after 479 iteration = [[0.40660775]]
# Cost after 480 iteration = [[0.40628235]]
# Cost after 481 iteration = [[0.40595759]]
# Cost after 482 iteration = [[0.40563346]]
# Cost after 483 iteration = [[0.40530996]]
# Cost after 484 iteration = [[0.40498708]]
# Cost after 485 iteration = [[0.40466484]]
# Cost after 486 iteration = [[0.40434322]]
# Cost after 487 iteration = [[0.40402223]]
# Cost after 488 iteration = [[0.40370185]]
# Cost after 489 iteration = [[0.4033821]]
# Cost after 490 iteration = [[0.40306297]]
# Cost after 491 iteration = [[0.40274445]]
# Cost after 492 iteration = [[0.40242655]]
# Cost after 493 iteration = [[0.40210926]]
# Cost after 494 iteration = [[0.40179259]]
# Cost after 495 iteration = [[0.40147652]]
# Cost after 496 iteration = [[0.40116106]]
# Cost after 497 iteration = [[0.40084621]]
# Cost after 498 iteration = [[0.40053197]]
# Cost after 499 iteration = [[0.40021833]]
# Cost after 500 iteration = [[0.39990529]]
# Cost after 501 iteration = [[0.39959285]]
# Cost after 502 iteration = [[0.399281]]
# Cost after 503 iteration = [[0.39896976]]
# Cost after 504 iteration = [[0.39865911]]
# Cost after 505 iteration = [[0.39834905]]
# Cost after 506 iteration = [[0.39803959]]
# Cost after 507 iteration = [[0.39773071]]
# Cost after 508 iteration = [[0.39742242]]
# Cost after 509 iteration = [[0.39711473]]
# Cost after 510 iteration = [[0.39680761]]
# Cost after 511 iteration = [[0.39650108]]
# Cost after 512 iteration = [[0.39619513]]
# Cost after 513 iteration = [[0.39588976]]
# Cost after 514 iteration = [[0.39558498]]
# Cost after 515 iteration = [[0.39528076]]
# Cost after 516 iteration = [[0.39497713]]
# Cost after 517 iteration = [[0.39467407]]
# Cost after 518 iteration = [[0.39437158]]
# Cost after 519 iteration = [[0.39406966]]
# Cost after 520 iteration = [[0.39376831]]
# Cost after 521 iteration = [[0.39346753]]
# Cost after 522 iteration = [[0.39316732]]
# Cost after 523 iteration = [[0.39286767]]
# Cost after 524 iteration = [[0.39256858]]
# Cost after 525 iteration = [[0.39227006]]
# Cost after 526 iteration = [[0.39197209]]
# Cost after 527 iteration = [[0.39167469]]
# Cost after 528 iteration = [[0.39137784]]
# Cost after 529 iteration = [[0.39108155]]
# Cost after 530 iteration = [[0.39078581]]
# Cost after 531 iteration = [[0.39049063]]
# Cost after 532 iteration = [[0.39019599]]
# Cost after 533 iteration = [[0.38990191]]
# Cost after 534 iteration = [[0.38960837]]
# Cost after 535 iteration = [[0.38931538]]
# Cost after 536 iteration = [[0.38902294]]
# Cost after 537 iteration = [[0.38873104]]
# Cost after 538 iteration = [[0.38843968]]
# Cost after 539 iteration = [[0.38814887]]
# Cost after 540 iteration = [[0.38785859]]
# Cost after 541 iteration = [[0.38756885]]
# Cost after 542 iteration = [[0.38727965]]
# Cost after 543 iteration = [[0.38699098]]
# Cost after 544 iteration = [[0.38670285]]
# Cost after 545 iteration = [[0.38641525]]
# Cost after 546 iteration = [[0.38612818]]
# Cost after 547 iteration = [[0.38584164]]
# Cost after 548 iteration = [[0.38555563]]
# Cost after 549 iteration = [[0.38527014]]
# Cost after 550 iteration = [[0.38498518]]
# Cost after 551 iteration = [[0.38470074]]
# Cost after 552 iteration = [[0.38441683]]
# Cost after 553 iteration = [[0.38413344]]
# Cost after 554 iteration = [[0.38385056]]
# Cost after 555 iteration = [[0.38356821]]
# Cost after 556 iteration = [[0.38328637]]
# Cost after 557 iteration = [[0.38300505]]
# Cost after 558 iteration = [[0.38272424]]
# Cost after 559 iteration = [[0.38244394]]
# Cost after 560 iteration = [[0.38216416]]
# Cost after 561 iteration = [[0.38188489]]
# Cost after 562 iteration = [[0.38160612]]
# Cost after 563 iteration = [[0.38132787]]
# Cost after 564 iteration = [[0.38105011]]
# Cost after 565 iteration = [[0.38077287]]
# Cost after 566 iteration = [[0.38049613]]
# Cost after 567 iteration = [[0.38021989]]
# Cost after 568 iteration = [[0.37994415]]
# Cost after 569 iteration = [[0.37966891]]
# Cost after 570 iteration = [[0.37939416]]
# Cost after 571 iteration = [[0.37911992]]
# Cost after 572 iteration = [[0.37884617]]
# Cost after 573 iteration = [[0.37857292]]
# Cost after 574 iteration = [[0.37830015]]
# Cost after 575 iteration = [[0.37802788]]
# Cost after 576 iteration = [[0.37775611]]
# Cost after 577 iteration = [[0.37748482]]
# Cost after 578 iteration = [[0.37721401]]
# Cost after 579 iteration = [[0.3769437]]
# Cost after 580 iteration = [[0.37667387]]
# Cost after 581 iteration = [[0.37640452]]
# Cost after 582 iteration = [[0.37613566]]
# Cost after 583 iteration = [[0.37586728]]
# Cost after 584 iteration = [[0.37559938]]
# Cost after 585 iteration = [[0.37533196]]
# Cost after 586 iteration = [[0.37506501]]
# Cost after 587 iteration = [[0.37479854]]
# Cost after 588 iteration = [[0.37453255]]
# Cost after 589 iteration = [[0.37426704]]
# Cost after 590 iteration = [[0.37400199]]
# Cost after 591 iteration = [[0.37373742]]
# Cost after 592 iteration = [[0.37347332]]
# Cost after 593 iteration = [[0.37320968]]
# Cost after 594 iteration = [[0.37294652]]
# Cost after 595 iteration = [[0.37268382]]
# Cost after 596 iteration = [[0.37242159]]
# Cost after 597 iteration = [[0.37215982]]
# Cost after 598 iteration = [[0.37189852]]
# Cost after 599 iteration = [[0.37163768]]
# Cost after 600 iteration = [[0.3713773]]
# Cost after 601 iteration = [[0.37111738]]
# Cost after 602 iteration = [[0.37085792]]
# Cost after 603 iteration = [[0.37059891]]
# Cost after 604 iteration = [[0.37034037]]
# Cost after 605 iteration = [[0.37008227]]
# Cost after 606 iteration = [[0.36982463]]
# Cost after 607 iteration = [[0.36956745]]
# Cost after 608 iteration = [[0.36931071]]
# Cost after 609 iteration = [[0.36905443]]
# Cost after 610 iteration = [[0.3687986]]
# Cost after 611 iteration = [[0.36854321]]
# Cost after 612 iteration = [[0.36828827]]
# Cost after 613 iteration = [[0.36803378]]
# Cost after 614 iteration = [[0.36777973]]
# Cost after 615 iteration = [[0.36752613]]
# Cost after 616 iteration = [[0.36727297]]
# Cost after 617 iteration = [[0.36702025]]
# Cost after 618 iteration = [[0.36676797]]
# Cost after 619 iteration = [[0.36651613]]
# Cost after 620 iteration = [[0.36626473]]
# Cost after 621 iteration = [[0.36601376]]
# Cost after 622 iteration = [[0.36576323]]
# Cost after 623 iteration = [[0.36551314]]
# Cost after 624 iteration = [[0.36526348]]
# Cost after 625 iteration = [[0.36501425]]
# Cost after 626 iteration = [[0.36476546]]
# Cost after 627 iteration = [[0.36451709]]
# Cost after 628 iteration = [[0.36426916]]
# Cost after 629 iteration = [[0.36402165]]
# Cost after 630 iteration = [[0.36377457]]
# Cost after 631 iteration = [[0.36352792]]
# Cost after 632 iteration = [[0.36328169]]
# Cost after 633 iteration = [[0.36303589]]
# Cost after 634 iteration = [[0.36279051]]
# Cost after 635 iteration = [[0.36254555]]
# Cost after 636 iteration = [[0.36230101]]
# Cost after 637 iteration = [[0.36205689]]
# Cost after 638 iteration = [[0.36181319]]
# Cost after 639 iteration = [[0.36156991]]
# Cost after 640 iteration = [[0.36132705]]
# Cost after 641 iteration = [[0.3610846]]
# Cost after 642 iteration = [[0.36084257]]
# Cost after 643 iteration = [[0.36060095]]
# Cost after 644 iteration = [[0.36035974]]
# Cost after 645 iteration = [[0.36011894]]
# Cost after 646 iteration = [[0.35987856]]
# Cost after 647 iteration = [[0.35963858]]
# Cost after 648 iteration = [[0.35939902]]
# Cost after 649 iteration = [[0.35915986]]
# Cost after 650 iteration = [[0.35892111]]
# Cost after 651 iteration = [[0.35868276]]
# Cost after 652 iteration = [[0.35844482]]
# Cost after 653 iteration = [[0.35820728]]
# Cost after 654 iteration = [[0.35797015]]
# Cost after 655 iteration = [[0.35773341]]
# Cost after 656 iteration = [[0.35749708]]
# Cost after 657 iteration = [[0.35726115]]
# Cost after 658 iteration = [[0.35702561]]
# Cost after 659 iteration = [[0.35679048]]
# Cost after 660 iteration = [[0.35655574]]
# Cost after 661 iteration = [[0.35632139]]
# Cost after 662 iteration = [[0.35608744]]
# Cost after 663 iteration = [[0.35585389]]
# Cost after 664 iteration = [[0.35562073]]
# Cost after 665 iteration = [[0.35538796]]
# Cost after 666 iteration = [[0.35515558]]
# Cost after 667 iteration = [[0.35492359]]
# Cost after 668 iteration = [[0.35469199]]
# Cost after 669 iteration = [[0.35446078]]
# Cost after 670 iteration = [[0.35422995]]
# Cost after 671 iteration = [[0.35399951]]
# Cost after 672 iteration = [[0.35376946]]
# Cost after 673 iteration = [[0.35353979]]
# Cost after 674 iteration = [[0.35331051]]
# Cost after 675 iteration = [[0.35308161]]
# Cost after 676 iteration = [[0.35285308]]
# Cost after 677 iteration = [[0.35262495]]
# Cost after 678 iteration = [[0.35239719]]
# Cost after 679 iteration = [[0.3521698]]
# Cost after 680 iteration = [[0.3519428]]
# Cost after 681 iteration = [[0.35171618]]
# Cost after 682 iteration = [[0.35148993]]
# Cost after 683 iteration = [[0.35126405]]
# Cost after 684 iteration = [[0.35103855]]
# Cost after 685 iteration = [[0.35081343]]
# Cost after 686 iteration = [[0.35058867]]
# Cost after 687 iteration = [[0.35036429]]
# Cost after 688 iteration = [[0.35014028]]
# Cost after 689 iteration = [[0.34991664]]
# Cost after 690 iteration = [[0.34969336]]
# Cost after 691 iteration = [[0.34947046]]
# Cost after 692 iteration = [[0.34924792]]
# Cost after 693 iteration = [[0.34902575]]
# Cost after 694 iteration = [[0.34880395]]
# Cost after 695 iteration = [[0.34858251]]
# Cost after 696 iteration = [[0.34836143]]
# Cost after 697 iteration = [[0.34814072]]
# Cost after 698 iteration = [[0.34792037]]
# Cost after 699 iteration = [[0.34770038]]
# Cost after 700 iteration = [[0.34748075]]
# Cost after 701 iteration = [[0.34726148]]
# Cost after 702 iteration = [[0.34704257]]
# Cost after 703 iteration = [[0.34682401]]
# Cost after 704 iteration = [[0.34660581]]
# Cost after 705 iteration = [[0.34638797]]
# Cost after 706 iteration = [[0.34617049]]
# Cost after 707 iteration = [[0.34595336]]
# Cost after 708 iteration = [[0.34573658]]
# Cost after 709 iteration = [[0.34552016]]
# Cost after 710 iteration = [[0.34530408]]
# Cost after 711 iteration = [[0.34508836]]
# Cost after 712 iteration = [[0.34487299]]
# Cost after 713 iteration = [[0.34465797]]
# Cost after 714 iteration = [[0.3444433]]
# Cost after 715 iteration = [[0.34422897]]
# Cost after 716 iteration = [[0.34401499]]
# Cost after 717 iteration = [[0.34380136]]
# Cost after 718 iteration = [[0.34358807]]
# Cost after 719 iteration = [[0.34337513]]
# Cost after 720 iteration = [[0.34316253]]
# Cost after 721 iteration = [[0.34295028]]
# Cost after 722 iteration = [[0.34273836]]
# Cost after 723 iteration = [[0.34252679]]
# Cost after 724 iteration = [[0.34231556]]
# Cost after 725 iteration = [[0.34210467]]
# Cost after 726 iteration = [[0.34189412]]
# Cost after 727 iteration = [[0.3416839]]
# Cost after 728 iteration = [[0.34147402]]
# Cost after 729 iteration = [[0.34126448]]
# Cost after 730 iteration = [[0.34105528]]
# Cost after 731 iteration = [[0.34084641]]
# Cost after 732 iteration = [[0.34063787]]
# Cost after 733 iteration = [[0.34042967]]
# Cost after 734 iteration = [[0.3402218]]
# Cost after 735 iteration = [[0.34001427]]
# Cost after 736 iteration = [[0.33980706]]
# Cost after 737 iteration = [[0.33960019]]
# Cost after 738 iteration = [[0.33939364]]
# Cost after 739 iteration = [[0.33918742]]
# Cost after 740 iteration = [[0.33898154]]
# Cost after 741 iteration = [[0.33877597]]
# Cost after 742 iteration = [[0.33857074]]
# Cost after 743 iteration = [[0.33836583]]
# Cost after 744 iteration = [[0.33816125]]
# Cost after 745 iteration = [[0.33795699]]
# Cost after 746 iteration = [[0.33775305]]
# Cost after 747 iteration = [[0.33754944]]
# Cost after 748 iteration = [[0.33734615]]
# Cost after 749 iteration = [[0.33714318]]
# Cost after 750 iteration = [[0.33694053]]
# Cost after 751 iteration = [[0.33673821]]
# Cost after 752 iteration = [[0.3365362]]
# Cost after 753 iteration = [[0.33633451]]
# Cost after 754 iteration = [[0.33613313]]
# Cost after 755 iteration = [[0.33593208]]
# Cost after 756 iteration = [[0.33573134]]
# Cost after 757 iteration = [[0.33553091]]
# Cost after 758 iteration = [[0.33533081]]
# Cost after 759 iteration = [[0.33513101]]
# Cost after 760 iteration = [[0.33493153]]
# Cost after 761 iteration = [[0.33473236]]
# Cost after 762 iteration = [[0.3345335]]
# Cost after 763 iteration = [[0.33433496]]
# Cost after 764 iteration = [[0.33413673]]
# Cost after 765 iteration = [[0.3339388]]
# Cost after 766 iteration = [[0.33374119]]
# Cost after 767 iteration = [[0.33354388]]
# Cost after 768 iteration = [[0.33334688]]
# Cost after 769 iteration = [[0.33315019]]
# Cost after 770 iteration = [[0.3329538]]
# Cost after 771 iteration = [[0.33275772]]
# Cost after 772 iteration = [[0.33256195]]
# Cost after 773 iteration = [[0.33236648]]
# Cost after 774 iteration = [[0.33217131]]
# Cost after 775 iteration = [[0.33197645]]
# Cost after 776 iteration = [[0.33178189]]
# Cost after 777 iteration = [[0.33158763]]
# Cost after 778 iteration = [[0.33139367]]
# Cost after 779 iteration = [[0.33120001]]
# Cost after 780 iteration = [[0.33100665]]
# Cost after 781 iteration = [[0.33081359]]
# Cost after 782 iteration = [[0.33062083]]
# Cost after 783 iteration = [[0.33042836]]
# Cost after 784 iteration = [[0.3302362]]
# Cost after 785 iteration = [[0.33004433]]
# Cost after 786 iteration = [[0.32985275]]
# Cost after 787 iteration = [[0.32966147]]
# Cost after 788 iteration = [[0.32947049]]
# Cost after 789 iteration = [[0.32927979]]
# Cost after 790 iteration = [[0.32908939]]
# Cost after 791 iteration = [[0.32889929]]
# Cost after 792 iteration = [[0.32870947]]
# Cost after 793 iteration = [[0.32851995]]
# Cost after 794 iteration = [[0.32833071]]
# Cost after 795 iteration = [[0.32814177]]
# Cost after 796 iteration = [[0.32795311]]
# Cost after 797 iteration = [[0.32776475]]
# Cost after 798 iteration = [[0.32757667]]
# Cost after 799 iteration = [[0.32738888]]
# Cost after 800 iteration = [[0.32720137]]
# Cost after 801 iteration = [[0.32701415]]
# Cost after 802 iteration = [[0.32682722]]
# Cost after 803 iteration = [[0.32664057]]
# Cost after 804 iteration = [[0.3264542]]
# Cost after 805 iteration = [[0.32626812]]
# Cost after 806 iteration = [[0.32608232]]
# Cost after 807 iteration = [[0.3258968]]
# Cost after 808 iteration = [[0.32571157]]
# Cost after 809 iteration = [[0.32552661]]
# Cost after 810 iteration = [[0.32534194]]
# Cost after 811 iteration = [[0.32515754]]
# Cost after 812 iteration = [[0.32497343]]
# Cost after 813 iteration = [[0.32478959]]
# Cost after 814 iteration = [[0.32460603]]
# Cost after 815 iteration = [[0.32442275]]
# Cost after 816 iteration = [[0.32423974]]
# Cost after 817 iteration = [[0.32405701]]
# Cost after 818 iteration = [[0.32387456]]
# Cost after 819 iteration = [[0.32369238]]
# Cost after 820 iteration = [[0.32351048]]
# Cost after 821 iteration = [[0.32332884]]
# Cost after 822 iteration = [[0.32314749]]
# Cost after 823 iteration = [[0.3229664]]
# Cost after 824 iteration = [[0.32278559]]
# Cost after 825 iteration = [[0.32260504]]
# Cost after 826 iteration = [[0.32242477]]
# Cost after 827 iteration = [[0.32224477]]
# Cost after 828 iteration = [[0.32206503]]
# Cost after 829 iteration = [[0.32188557]]
# Cost after 830 iteration = [[0.32170637]]
# Cost after 831 iteration = [[0.32152745]]
# Cost after 832 iteration = [[0.32134879]]
# Cost after 833 iteration = [[0.32117039]]
# Cost after 834 iteration = [[0.32099226]]
# Cost after 835 iteration = [[0.3208144]]
# Cost after 836 iteration = [[0.3206368]]
# Cost after 837 iteration = [[0.32045947]]
# Cost after 838 iteration = [[0.3202824]]
# Cost after 839 iteration = [[0.32010559]]
# Cost after 840 iteration = [[0.31992904]]
# Cost after 841 iteration = [[0.31975276]]
# Cost after 842 iteration = [[0.31957674]]
# Cost after 843 iteration = [[0.31940098]]
# Cost after 844 iteration = [[0.31922548]]
# Cost after 845 iteration = [[0.31905024]]
# Cost after 846 iteration = [[0.31887526]]
# Cost after 847 iteration = [[0.31870054]]
# Cost after 848 iteration = [[0.31852607]]
# Cost after 849 iteration = [[0.31835187]]
# Cost after 850 iteration = [[0.31817792]]
# Cost after 851 iteration = [[0.31800422]]
# Cost after 852 iteration = [[0.31783078]]
# Cost after 853 iteration = [[0.3176576]]
# Cost after 854 iteration = [[0.31748467]]
# Cost after 855 iteration = [[0.317312]]
# Cost after 856 iteration = [[0.31713958]]
# Cost after 857 iteration = [[0.31696741]]
# Cost after 858 iteration = [[0.3167955]]
# Cost after 859 iteration = [[0.31662384]]
# Cost after 860 iteration = [[0.31645243]]
# Cost after 861 iteration = [[0.31628127]]
# Cost after 862 iteration = [[0.31611036]]
# Cost after 863 iteration = [[0.3159397]]
# Cost after 864 iteration = [[0.31576929]]
# Cost after 865 iteration = [[0.31559913]]
# Cost after 866 iteration = [[0.31542922]]
# Cost after 867 iteration = [[0.31525955]]
# Cost after 868 iteration = [[0.31509014]]
# Cost after 869 iteration = [[0.31492097]]
# Cost after 870 iteration = [[0.31475204]]
# Cost after 871 iteration = [[0.31458336]]
# Cost after 872 iteration = [[0.31441493]]
# Cost after 873 iteration = [[0.31424674]]
# Cost after 874 iteration = [[0.3140788]]
# Cost after 875 iteration = [[0.3139111]]
# Cost after 876 iteration = [[0.31374364]]
# Cost after 877 iteration = [[0.31357642]]
# Cost after 878 iteration = [[0.31340945]]
# Cost after 879 iteration = [[0.31324272]]
# Cost after 880 iteration = [[0.31307623]]
# Cost after 881 iteration = [[0.31290998]]
# Cost after 882 iteration = [[0.31274397]]
# Cost after 883 iteration = [[0.3125782]]
# Cost after 884 iteration = [[0.31241267]]
# Cost after 885 iteration = [[0.31224738]]
# Cost after 886 iteration = [[0.31208233]]
# Cost after 887 iteration = [[0.31191751]]
# Cost after 888 iteration = [[0.31175293]]
# Cost after 889 iteration = [[0.31158859]]
# Cost after 890 iteration = [[0.31142448]]
# Cost after 891 iteration = [[0.31126061]]
# Cost after 892 iteration = [[0.31109697]]
# Cost after 893 iteration = [[0.31093357]]
# Cost after 894 iteration = [[0.31077041]]
# Cost after 895 iteration = [[0.31060747]]
# Cost after 896 iteration = [[0.31044477]]
# Cost after 897 iteration = [[0.3102823]]
# Cost after 898 iteration = [[0.31012007]]
# Cost after 899 iteration = [[0.30995807]]
# Cost after 900 iteration = [[0.30979629]]
# Cost after 901 iteration = [[0.30963475]]
# Cost after 902 iteration = [[0.30947344]]
# Cost after 903 iteration = [[0.30931236]]
# Cost after 904 iteration = [[0.30915151]]
# Cost after 905 iteration = [[0.30899088]]
# Cost after 906 iteration = [[0.30883049]]
# Cost after 907 iteration = [[0.30867032]]
# Cost after 908 iteration = [[0.30851038]]
# Cost after 909 iteration = [[0.30835067]]
# Cost after 910 iteration = [[0.30819118]]
# Cost after 911 iteration = [[0.30803192]]
# Cost after 912 iteration = [[0.30787289]]
# Cost after 913 iteration = [[0.30771408]]
# Cost after 914 iteration = [[0.30755549]]
# Cost after 915 iteration = [[0.30739713]]
# Cost after 916 iteration = [[0.307239]]
# Cost after 917 iteration = [[0.30708108]]
# Cost after 918 iteration = [[0.30692339]]
# Cost after 919 iteration = [[0.30676592]]
# Cost after 920 iteration = [[0.30660868]]
# Cost after 921 iteration = [[0.30645165]]
# Cost after 922 iteration = [[0.30629485]]
# Cost after 923 iteration = [[0.30613827]]
# Cost after 924 iteration = [[0.3059819]]
# Cost after 925 iteration = [[0.30582576]]
# Cost after 926 iteration = [[0.30566983]]
# Cost after 927 iteration = [[0.30551413]]
# Cost after 928 iteration = [[0.30535864]]
# Cost after 929 iteration = [[0.30520337]]
# Cost after 930 iteration = [[0.30504832]]
# Cost after 931 iteration = [[0.30489348]]
# Cost after 932 iteration = [[0.30473886]]
# Cost after 933 iteration = [[0.30458446]]
# Cost after 934 iteration = [[0.30443027]]
# Cost after 935 iteration = [[0.3042763]]
# Cost after 936 iteration = [[0.30412255]]
# Cost after 937 iteration = [[0.303969]]
# Cost after 938 iteration = [[0.30381567]]
# Cost after 939 iteration = [[0.30366256]]
# Cost after 940 iteration = [[0.30350966]]
# Cost after 941 iteration = [[0.30335697]]
# Cost after 942 iteration = [[0.30320449]]
# Cost after 943 iteration = [[0.30305222]]
# Cost after 944 iteration = [[0.30290017]]
# Cost after 945 iteration = [[0.30274832]]
# Cost after 946 iteration = [[0.30259669]]
# Cost after 947 iteration = [[0.30244527]]
# Cost after 948 iteration = [[0.30229405]]
# Cost after 949 iteration = [[0.30214305]]
# Cost after 950 iteration = [[0.30199225]]
# Cost after 951 iteration = [[0.30184167]]
# Cost after 952 iteration = [[0.30169129]]
# Cost after 953 iteration = [[0.30154112]]
# Cost after 954 iteration = [[0.30139115]]
# Cost after 955 iteration = [[0.30124139]]
# Cost after 956 iteration = [[0.30109184]]
# Cost after 957 iteration = [[0.3009425]]
# Cost after 958 iteration = [[0.30079335]]
# Cost after 959 iteration = [[0.30064442]]
# Cost after 960 iteration = [[0.30049569]]
# Cost after 961 iteration = [[0.30034716]]
# Cost after 962 iteration = [[0.30019884]]
# Cost after 963 iteration = [[0.30005072]]
# Cost after 964 iteration = [[0.2999028]]
# Cost after 965 iteration = [[0.29975509]]
# Cost after 966 iteration = [[0.29960758]]
# Cost after 967 iteration = [[0.29946027]]
# Cost after 968 iteration = [[0.29931316]]
# Cost after 969 iteration = [[0.29916625]]
# Cost after 970 iteration = [[0.29901955]]
# Cost after 971 iteration = [[0.29887304]]
# Cost after 972 iteration = [[0.29872673]]
# Cost after 973 iteration = [[0.29858062]]
# Cost after 974 iteration = [[0.29843472]]
# Cost after 975 iteration = [[0.29828901]]
# Cost after 976 iteration = [[0.29814349]]
# Cost after 977 iteration = [[0.29799818]]
# Cost after 978 iteration = [[0.29785306]]
# Cost after 979 iteration = [[0.29770814]]
# Cost after 980 iteration = [[0.29756342]]
# Cost after 981 iteration = [[0.29741889]]
# Cost after 982 iteration = [[0.29727456]]
# Cost after 983 iteration = [[0.29713043]]
# Cost after 984 iteration = [[0.29698649]]
# Cost after 985 iteration = [[0.29684274]]
# Cost after 986 iteration = [[0.29669919]]
# Cost after 987 iteration = [[0.29655584]]
# Cost after 988 iteration = [[0.29641267]]
# Cost after 989 iteration = [[0.2962697]]
# Cost after 990 iteration = [[0.29612692]]
# Cost after 991 iteration = [[0.29598434]]
# Cost after 992 iteration = [[0.29584195]]
# Cost after 993 iteration = [[0.29569974]]
# Cost after 994 iteration = [[0.29555773]]
# Cost after 995 iteration = [[0.29541591]]
# Cost after 996 iteration = [[0.29527429]]
# Cost after 997 iteration = [[0.29513285]]
# Cost after 998 iteration = [[0.2949916]]
# Cost after 999 iteration = [[0.29485054]]
# Cost after 1000 iteration = [[0.29470967]]
# Cost after 1001 iteration = [[0.29456899]]
# Cost after 1002 iteration = [[0.2944285]]
# Cost after 1003 iteration = [[0.29428819]]
# Cost after 1004 iteration = [[0.29414807]]
# Cost after 1005 iteration = [[0.29400814]]
# Cost after 1006 iteration = [[0.2938684]]
# Cost after 1007 iteration = [[0.29372884]]
# Cost after 1008 iteration = [[0.29358947]]
# Cost after 1009 iteration = [[0.29345029]]
# Cost after 1010 iteration = [[0.29331129]]
# Cost after 1011 iteration = [[0.29317247]]
# Cost after 1012 iteration = [[0.29303384]]
# Cost after 1013 iteration = [[0.2928954]]
# Cost after 1014 iteration = [[0.29275713]]
# Cost after 1015 iteration = [[0.29261906]]
# Cost after 1016 iteration = [[0.29248116]]
# Cost after 1017 iteration = [[0.29234345]]
# Cost after 1018 iteration = [[0.29220592]]
# Cost after 1019 iteration = [[0.29206857]]
# Cost after 1020 iteration = [[0.29193141]]
# Cost after 1021 iteration = [[0.29179442]]
# Cost after 1022 iteration = [[0.29165762]]
# Cost after 1023 iteration = [[0.291521]]
# Cost after 1024 iteration = [[0.29138456]]
# Cost after 1025 iteration = [[0.2912483]]
# Cost after 1026 iteration = [[0.29111222]]
# Cost after 1027 iteration = [[0.29097631]]
# Cost after 1028 iteration = [[0.29084059]]
# Cost after 1029 iteration = [[0.29070505]]
# Cost after 1030 iteration = [[0.29056968]]
# Cost after 1031 iteration = [[0.29043449]]
# Cost after 1032 iteration = [[0.29029948]]
# Cost after 1033 iteration = [[0.29016465]]
# Cost after 1034 iteration = [[0.29003]]
# Cost after 1035 iteration = [[0.28989552]]
# Cost after 1036 iteration = [[0.28976121]]
# Cost after 1037 iteration = [[0.28962709]]
# Cost after 1038 iteration = [[0.28949314]]
# Cost after 1039 iteration = [[0.28935936]]
# Cost after 1040 iteration = [[0.28922576]]
# Cost after 1041 iteration = [[0.28909233]]
# Cost after 1042 iteration = [[0.28895908]]
# Cost after 1043 iteration = [[0.28882601]]
# Cost after 1044 iteration = [[0.2886931]]
# Cost after 1045 iteration = [[0.28856037]]
# Cost after 1046 iteration = [[0.28842781]]
# Cost after 1047 iteration = [[0.28829543]]
# Cost after 1048 iteration = [[0.28816322]]
# Cost after 1049 iteration = [[0.28803118]]
# Cost after 1050 iteration = [[0.28789931]]
# Cost after 1051 iteration = [[0.28776761]]
# Cost after 1052 iteration = [[0.28763608]]
# Cost after 1053 iteration = [[0.28750473]]
# Cost after 1054 iteration = [[0.28737354]]
# Cost after 1055 iteration = [[0.28724253]]
# Cost after 1056 iteration = [[0.28711168]]
# Cost after 1057 iteration = [[0.28698101]]
# Cost after 1058 iteration = [[0.2868505]]
# Cost after 1059 iteration = [[0.28672016]]
# Cost after 1060 iteration = [[0.28658999]]
# Cost after 1061 iteration = [[0.28645999]]
# Cost after 1062 iteration = [[0.28633016]]
# Cost after 1063 iteration = [[0.28620049]]
# Cost after 1064 iteration = [[0.28607099]]
# Cost after 1065 iteration = [[0.28594166]]
# Cost after 1066 iteration = [[0.2858125]]
# Cost after 1067 iteration = [[0.2856835]]
# Cost after 1068 iteration = [[0.28555466]]
# Cost after 1069 iteration = [[0.285426]]
# Cost after 1070 iteration = [[0.28529749]]
# Cost after 1071 iteration = [[0.28516916]]
# Cost after 1072 iteration = [[0.28504099]]
# Cost after 1073 iteration = [[0.28491298]]
# Cost after 1074 iteration = [[0.28478513]]
# Cost after 1075 iteration = [[0.28465745]]
# Cost after 1076 iteration = [[0.28452994]]
# Cost after 1077 iteration = [[0.28440258]]
# Cost after 1078 iteration = [[0.28427539]]
# Cost after 1079 iteration = [[0.28414837]]
# Cost after 1080 iteration = [[0.2840215]]
# Cost after 1081 iteration = [[0.2838948]]
# Cost after 1082 iteration = [[0.28376826]]
# Cost after 1083 iteration = [[0.28364188]]
# Cost after 1084 iteration = [[0.28351566]]
# Cost after 1085 iteration = [[0.2833896]]
# Cost after 1086 iteration = [[0.2832637]]
# Cost after 1087 iteration = [[0.28313796]]
# Cost after 1088 iteration = [[0.28301238]]
# Cost after 1089 iteration = [[0.28288696]]
# Cost after 1090 iteration = [[0.28276171]]
# Cost after 1091 iteration = [[0.28263661]]
# Cost after 1092 iteration = [[0.28251166]]
# Cost after 1093 iteration = [[0.28238688]]
# Cost after 1094 iteration = [[0.28226226]]
# Cost after 1095 iteration = [[0.28213779]]
# Cost after 1096 iteration = [[0.28201348]]
# Cost after 1097 iteration = [[0.28188933]]
# Cost after 1098 iteration = [[0.28176533]]
# Cost after 1099 iteration = [[0.28164149]]
# Cost after 1100 iteration = [[0.28151781]]
# Cost after 1101 iteration = [[0.28139428]]
# Cost after 1102 iteration = [[0.28127091]]
# Cost after 1103 iteration = [[0.2811477]]
# Cost after 1104 iteration = [[0.28102464]]
# Cost after 1105 iteration = [[0.28090173]]
# Cost after 1106 iteration = [[0.28077898]]
# Cost after 1107 iteration = [[0.28065639]]
# Cost after 1108 iteration = [[0.28053394]]
# Cost after 1109 iteration = [[0.28041166]]
# Cost after 1110 iteration = [[0.28028952]]
# Cost after 1111 iteration = [[0.28016754]]
# Cost after 1112 iteration = [[0.28004571]]
# Cost after 1113 iteration = [[0.27992404]]
# Cost after 1114 iteration = [[0.27980251]]
# Cost after 1115 iteration = [[0.27968114]]
# Cost after 1116 iteration = [[0.27955992]]
# Cost after 1117 iteration = [[0.27943885]]
# Cost after 1118 iteration = [[0.27931794]]
# Cost after 1119 iteration = [[0.27919717]]
# Cost after 1120 iteration = [[0.27907656]]
# Cost after 1121 iteration = [[0.27895609]]
# Cost after 1122 iteration = [[0.27883578]]
# Cost after 1123 iteration = [[0.27871561]]
# Cost after 1124 iteration = [[0.2785956]]
# Cost after 1125 iteration = [[0.27847573]]
# Cost after 1126 iteration = [[0.27835602]]
# Cost after 1127 iteration = [[0.27823645]]
# Cost after 1128 iteration = [[0.27811703]]
# Cost after 1129 iteration = [[0.27799776]]
# Cost after 1130 iteration = [[0.27787864]]
# Cost after 1131 iteration = [[0.27775966]]
# Cost after 1132 iteration = [[0.27764084]]
# Cost after 1133 iteration = [[0.27752216]]
# Cost after 1134 iteration = [[0.27740362]]
# Cost after 1135 iteration = [[0.27728524]]
# Cost after 1136 iteration = [[0.277167]]
# Cost after 1137 iteration = [[0.2770489]]
# Cost after 1138 iteration = [[0.27693095]]
# Cost after 1139 iteration = [[0.27681315]]
# Cost after 1140 iteration = [[0.27669549]]
# Cost after 1141 iteration = [[0.27657798]]
# Cost after 1142 iteration = [[0.27646062]]
# Cost after 1143 iteration = [[0.27634339]]
# Cost after 1144 iteration = [[0.27622631]]
# Cost after 1145 iteration = [[0.27610938]]
# Cost after 1146 iteration = [[0.27599259]]
# Cost after 1147 iteration = [[0.27587594]]
# Cost after 1148 iteration = [[0.27575944]]
# Cost after 1149 iteration = [[0.27564308]]
# Cost after 1150 iteration = [[0.27552686]]
# Cost after 1151 iteration = [[0.27541078]]
# Cost after 1152 iteration = [[0.27529485]]
# Cost after 1153 iteration = [[0.27517906]]
# Cost after 1154 iteration = [[0.27506341]]
# Cost after 1155 iteration = [[0.2749479]]
# Cost after 1156 iteration = [[0.27483254]]
# Cost after 1157 iteration = [[0.27471731]]
# Cost after 1158 iteration = [[0.27460222]]
# Cost after 1159 iteration = [[0.27448728]]
# Cost after 1160 iteration = [[0.27437248]]
# Cost after 1161 iteration = [[0.27425781]]
# Cost after 1162 iteration = [[0.27414329]]
# Cost after 1163 iteration = [[0.2740289]]
# Cost after 1164 iteration = [[0.27391466]]
# Cost after 1165 iteration = [[0.27380055]]
# Cost after 1166 iteration = [[0.27368658]]
# Cost after 1167 iteration = [[0.27357275]]
# Cost after 1168 iteration = [[0.27345906]]
# Cost after 1169 iteration = [[0.27334551]]
# Cost after 1170 iteration = [[0.27323209]]
# Cost after 1171 iteration = [[0.27311881]]
# Cost after 1172 iteration = [[0.27300567]]
# Cost after 1173 iteration = [[0.27289267]]
# Cost after 1174 iteration = [[0.2727798]]
# Cost after 1175 iteration = [[0.27266707]]
# Cost after 1176 iteration = [[0.27255447]]
# Cost after 1177 iteration = [[0.27244202]]
# Cost after 1178 iteration = [[0.27232969]]
# Cost after 1179 iteration = [[0.27221751]]
# Cost after 1180 iteration = [[0.27210545]]
# Cost after 1181 iteration = [[0.27199354]]
# Cost after 1182 iteration = [[0.27188176]]
# Cost after 1183 iteration = [[0.27177011]]
# Cost after 1184 iteration = [[0.2716586]]
# Cost after 1185 iteration = [[0.27154722]]
# Cost after 1186 iteration = [[0.27143597]]
# Cost after 1187 iteration = [[0.27132486]]
# Cost after 1188 iteration = [[0.27121388]]
# Cost after 1189 iteration = [[0.27110304]]
# Cost after 1190 iteration = [[0.27099233]]
# Cost after 1191 iteration = [[0.27088175]]
# Cost after 1192 iteration = [[0.2707713]]
# Cost after 1193 iteration = [[0.27066099]]
# Cost after 1194 iteration = [[0.27055081]]
# Cost after 1195 iteration = [[0.27044076]]
# Cost after 1196 iteration = [[0.27033084]]
# Cost after 1197 iteration = [[0.27022105]]
# Cost after 1198 iteration = [[0.2701114]]
# Cost after 1199 iteration = [[0.27000187]]
# Cost after 1200 iteration = [[0.26989248]]
# Cost after 1201 iteration = [[0.26978321]]
# Cost after 1202 iteration = [[0.26967408]]
# Cost after 1203 iteration = [[0.26956507]]
# Cost after 1204 iteration = [[0.2694562]]
# Cost after 1205 iteration = [[0.26934745]]
# Cost after 1206 iteration = [[0.26923884]]
# Cost after 1207 iteration = [[0.26913035]]
# Cost after 1208 iteration = [[0.269022]]
# Cost after 1209 iteration = [[0.26891377]]
# Cost after 1210 iteration = [[0.26880567]]
# Cost after 1211 iteration = [[0.26869769]]
# Cost after 1212 iteration = [[0.26858985]]
# Cost after 1213 iteration = [[0.26848213]]
# Cost after 1214 iteration = [[0.26837454]]
# Cost after 1215 iteration = [[0.26826708]]
# Cost after 1216 iteration = [[0.26815975]]
# Cost after 1217 iteration = [[0.26805254]]
# Cost after 1218 iteration = [[0.26794546]]
# Cost after 1219 iteration = [[0.2678385]]
# Cost after 1220 iteration = [[0.26773167]]
# Cost after 1221 iteration = [[0.26762497]]
# Cost after 1222 iteration = [[0.26751839]]
# Cost after 1223 iteration = [[0.26741194]]
# Cost after 1224 iteration = [[0.26730562]]
# Cost after 1225 iteration = [[0.26719942]]
# Cost after 1226 iteration = [[0.26709334]]
# Cost after 1227 iteration = [[0.26698739]]
# Cost after 1228 iteration = [[0.26688156]]
# Cost after 1229 iteration = [[0.26677586]]
# Cost after 1230 iteration = [[0.26667028]]
# Cost after 1231 iteration = [[0.26656482]]
# Cost after 1232 iteration = [[0.26645949]]
# Cost after 1233 iteration = [[0.26635428]]
# Cost after 1234 iteration = [[0.2662492]]
# Cost after 1235 iteration = [[0.26614424]]
# Cost after 1236 iteration = [[0.2660394]]
# Cost after 1237 iteration = [[0.26593468]]
# Cost after 1238 iteration = [[0.26583009]]
# Cost after 1239 iteration = [[0.26572562]]
# Cost after 1240 iteration = [[0.26562126]]
# Cost after 1241 iteration = [[0.26551704]]
# Cost after 1242 iteration = [[0.26541293]]
# Cost after 1243 iteration = [[0.26530894]]
# Cost after 1244 iteration = [[0.26520508]]
# Cost after 1245 iteration = [[0.26510134]]
# Cost after 1246 iteration = [[0.26499771]]
# Cost after 1247 iteration = [[0.26489421]]
# Cost after 1248 iteration = [[0.26479083]]
# Cost after 1249 iteration = [[0.26468756]]
# Cost after 1250 iteration = [[0.26458442]]
# Cost after 1251 iteration = [[0.2644814]]
# Cost after 1252 iteration = [[0.2643785]]
# Cost after 1253 iteration = [[0.26427571]]
# Cost after 1254 iteration = [[0.26417305]]
# Cost after 1255 iteration = [[0.2640705]]
# Cost after 1256 iteration = [[0.26396807]]
# Cost after 1257 iteration = [[0.26386576]]
# Cost after 1258 iteration = [[0.26376357]]
# Cost after 1259 iteration = [[0.2636615]]
# Cost after 1260 iteration = [[0.26355954]]
# Cost after 1261 iteration = [[0.26345771]]
# Cost after 1262 iteration = [[0.26335599]]
# Cost after 1263 iteration = [[0.26325438]]
# Cost after 1264 iteration = [[0.2631529]]
# Cost after 1265 iteration = [[0.26305153]]
# Cost after 1266 iteration = [[0.26295028]]
# Cost after 1267 iteration = [[0.26284914]]
# Cost after 1268 iteration = [[0.26274812]]
# Cost after 1269 iteration = [[0.26264722]]
# Cost after 1270 iteration = [[0.26254643]]
# Cost after 1271 iteration = [[0.26244576]]
# Cost after 1272 iteration = [[0.2623452]]
# Cost after 1273 iteration = [[0.26224476]]
# Cost after 1274 iteration = [[0.26214443]]
# Cost after 1275 iteration = [[0.26204422]]
# Cost after 1276 iteration = [[0.26194413]]
# Cost after 1277 iteration = [[0.26184414]]
# Cost after 1278 iteration = [[0.26174428]]
# Cost after 1279 iteration = [[0.26164452]]
# Cost after 1280 iteration = [[0.26154488]]
# Cost after 1281 iteration = [[0.26144536]]
# Cost after 1282 iteration = [[0.26134594]]
# Cost after 1283 iteration = [[0.26124664]]
# Cost after 1284 iteration = [[0.26114746]]
# Cost after 1285 iteration = [[0.26104838]]
# Cost after 1286 iteration = [[0.26094942]]
# Cost after 1287 iteration = [[0.26085058]]
# Cost after 1288 iteration = [[0.26075184]]
# Cost after 1289 iteration = [[0.26065322]]
# Cost after 1290 iteration = [[0.26055471]]
# Cost after 1291 iteration = [[0.26045631]]
# Cost after 1292 iteration = [[0.26035802]]
# Cost after 1293 iteration = [[0.26025984]]
# Cost after 1294 iteration = [[0.26016178]]
# Cost after 1295 iteration = [[0.26006383]]
# Cost after 1296 iteration = [[0.25996598]]
# Cost after 1297 iteration = [[0.25986825]]
# Cost after 1298 iteration = [[0.25977063]]
# Cost after 1299 iteration = [[0.25967312]]
# Cost after 1300 iteration = [[0.25957572]]
# Cost after 1301 iteration = [[0.25947843]]
# Cost after 1302 iteration = [[0.25938124]]
# Cost after 1303 iteration = [[0.25928417]]
# Cost after 1304 iteration = [[0.25918721]]
# Cost after 1305 iteration = [[0.25909036]]
# Cost after 1306 iteration = [[0.25899361]]
# Cost after 1307 iteration = [[0.25889698]]
# Cost after 1308 iteration = [[0.25880045]]
# Cost after 1309 iteration = [[0.25870404]]
# Cost after 1310 iteration = [[0.25860773]]
# Cost after 1311 iteration = [[0.25851153]]
# Cost after 1312 iteration = [[0.25841543]]
# Cost after 1313 iteration = [[0.25831945]]
# Cost after 1314 iteration = [[0.25822357]]
# Cost after 1315 iteration = [[0.2581278]]
# Cost after 1316 iteration = [[0.25803214]]
# Cost after 1317 iteration = [[0.25793658]]
# Cost after 1318 iteration = [[0.25784113]]
# Cost after 1319 iteration = [[0.25774579]]
# Cost after 1320 iteration = [[0.25765056]]
# Cost after 1321 iteration = [[0.25755543]]
# Cost after 1322 iteration = [[0.2574604]]
# Cost after 1323 iteration = [[0.25736549]]
# Cost after 1324 iteration = [[0.25727068]]
# Cost after 1325 iteration = [[0.25717597]]
# Cost after 1326 iteration = [[0.25708137]]
# Cost after 1327 iteration = [[0.25698688]]
# Cost after 1328 iteration = [[0.25689249]]
# Cost after 1329 iteration = [[0.25679821]]
# Cost after 1330 iteration = [[0.25670403]]
# Cost after 1331 iteration = [[0.25660995]]
# Cost after 1332 iteration = [[0.25651598]]
# Cost after 1333 iteration = [[0.25642212]]
# Cost after 1334 iteration = [[0.25632836]]
# Cost after 1335 iteration = [[0.2562347]]
# Cost after 1336 iteration = [[0.25614115]]
# Cost after 1337 iteration = [[0.2560477]]
# Cost after 1338 iteration = [[0.25595435]]
# Cost after 1339 iteration = [[0.25586111]]
# Cost after 1340 iteration = [[0.25576797]]
# Cost after 1341 iteration = [[0.25567493]]
# Cost after 1342 iteration = [[0.255582]]
# Cost after 1343 iteration = [[0.25548917]]
# Cost after 1344 iteration = [[0.25539644]]
# Cost after 1345 iteration = [[0.25530381]]
# Cost after 1346 iteration = [[0.25521129]]
# Cost after 1347 iteration = [[0.25511887]]
# Cost after 1348 iteration = [[0.25502654]]
# Cost after 1349 iteration = [[0.25493433]]
# Cost after 1350 iteration = [[0.25484221]]
# Cost after 1351 iteration = [[0.25475019]]
# Cost after 1352 iteration = [[0.25465828]]
# Cost after 1353 iteration = [[0.25456646]]
# Cost after 1354 iteration = [[0.25447475]]
# Cost after 1355 iteration = [[0.25438314]]
# Cost after 1356 iteration = [[0.25429163]]
# Cost after 1357 iteration = [[0.25420022]]
# Cost after 1358 iteration = [[0.25410891]]
# Cost after 1359 iteration = [[0.25401769]]
# Cost after 1360 iteration = [[0.25392658]]
# Cost after 1361 iteration = [[0.25383557]]
# Cost after 1362 iteration = [[0.25374466]]
# Cost after 1363 iteration = [[0.25365385]]
# Cost after 1364 iteration = [[0.25356313]]
# Cost after 1365 iteration = [[0.25347252]]
# Cost after 1366 iteration = [[0.25338201]]
# Cost after 1367 iteration = [[0.25329159]]
# Cost after 1368 iteration = [[0.25320127]]
# Cost after 1369 iteration = [[0.25311105]]
# Cost after 1370 iteration = [[0.25302093]]
# Cost after 1371 iteration = [[0.25293091]]
# Cost after 1372 iteration = [[0.25284098]]
# Cost after 1373 iteration = [[0.25275115]]
# Cost after 1374 iteration = [[0.25266142]]
# Cost after 1375 iteration = [[0.25257179]]
# Cost after 1376 iteration = [[0.25248226]]
# Cost after 1377 iteration = [[0.25239282]]
# Cost after 1378 iteration = [[0.25230348]]
# Cost after 1379 iteration = [[0.25221424]]
# Cost after 1380 iteration = [[0.25212509]]
# Cost after 1381 iteration = [[0.25203604]]
# Cost after 1382 iteration = [[0.25194708]]
# Cost after 1383 iteration = [[0.25185823]]
# Cost after 1384 iteration = [[0.25176946]]
# Cost after 1385 iteration = [[0.2516808]]
# Cost after 1386 iteration = [[0.25159223]]
# Cost after 1387 iteration = [[0.25150375]]
# Cost after 1388 iteration = [[0.25141538]]
# Cost after 1389 iteration = [[0.25132709]]
# Cost after 1390 iteration = [[0.2512389]]
# Cost after 1391 iteration = [[0.25115081]]
# Cost after 1392 iteration = [[0.25106281]]
# Cost after 1393 iteration = [[0.25097491]]
# Cost after 1394 iteration = [[0.2508871]]
# Cost after 1395 iteration = [[0.25079939]]
# Cost after 1396 iteration = [[0.25071176]]
# Cost after 1397 iteration = [[0.25062424]]
# Cost after 1398 iteration = [[0.25053681]]
# Cost after 1399 iteration = [[0.25044947]]
# Cost after 1400 iteration = [[0.25036222]]
# Cost after 1401 iteration = [[0.25027507]]
# Cost after 1402 iteration = [[0.25018801]]
# Cost after 1403 iteration = [[0.25010105]]
# Cost after 1404 iteration = [[0.25001418]]
# Cost after 1405 iteration = [[0.2499274]]
# Cost after 1406 iteration = [[0.24984071]]
# Cost after 1407 iteration = [[0.24975412]]
# Cost after 1408 iteration = [[0.24966762]]
# Cost after 1409 iteration = [[0.24958121]]
# Cost after 1410 iteration = [[0.2494949]]
# Cost after 1411 iteration = [[0.24940867]]
# Cost after 1412 iteration = [[0.24932254]]
# Cost after 1413 iteration = [[0.2492365]]
# Cost after 1414 iteration = [[0.24915055]]
# Cost after 1415 iteration = [[0.2490647]]
# Cost after 1416 iteration = [[0.24897893]]
# Cost after 1417 iteration = [[0.24889326]]
# Cost after 1418 iteration = [[0.24880767]]
# Cost after 1419 iteration = [[0.24872218]]
# Cost after 1420 iteration = [[0.24863678]]
# Cost after 1421 iteration = [[0.24855147]]
# Cost after 1422 iteration = [[0.24846625]]
# Cost after 1423 iteration = [[0.24838112]]
# Cost after 1424 iteration = [[0.24829608]]
# Cost after 1425 iteration = [[0.24821113]]
# Cost after 1426 iteration = [[0.24812627]]
# Cost after 1427 iteration = [[0.2480415]]
# Cost after 1428 iteration = [[0.24795682]]
# Cost after 1429 iteration = [[0.24787223]]
# Cost after 1430 iteration = [[0.24778773]]
# Cost after 1431 iteration = [[0.24770331]]
# Cost after 1432 iteration = [[0.24761899]]
# Cost after 1433 iteration = [[0.24753476]]
# Cost after 1434 iteration = [[0.24745061]]
# Cost after 1435 iteration = [[0.24736656]]
# Cost after 1436 iteration = [[0.24728259]]
# Cost after 1437 iteration = [[0.24719871]]
# Cost after 1438 iteration = [[0.24711492]]
# Cost after 1439 iteration = [[0.24703121]]
# Cost after 1440 iteration = [[0.2469476]]
# Cost after 1441 iteration = [[0.24686407]]
# Cost after 1442 iteration = [[0.24678063]]
# Cost after 1443 iteration = [[0.24669728]]
# Cost after 1444 iteration = [[0.24661401]]
# Cost after 1445 iteration = [[0.24653084]]
# Cost after 1446 iteration = [[0.24644775]]
# Cost after 1447 iteration = [[0.24636474]]
# Cost after 1448 iteration = [[0.24628183]]
# Cost after 1449 iteration = [[0.246199]]
# Cost after 1450 iteration = [[0.24611626]]
# Cost after 1451 iteration = [[0.2460336]]
# Cost after 1452 iteration = [[0.24595103]]
# Cost after 1453 iteration = [[0.24586855]]
# Cost after 1454 iteration = [[0.24578615]]
# Cost after 1455 iteration = [[0.24570384]]
# Cost after 1456 iteration = [[0.24562161]]
# Cost after 1457 iteration = [[0.24553947]]
# Cost after 1458 iteration = [[0.24545742]]
# Cost after 1459 iteration = [[0.24537545]]
# Cost after 1460 iteration = [[0.24529357]]
# Cost after 1461 iteration = [[0.24521177]]
# Cost after 1462 iteration = [[0.24513005]]
# Cost after 1463 iteration = [[0.24504843]]
# Cost after 1464 iteration = [[0.24496688]]
# Cost after 1465 iteration = [[0.24488542]]
# Cost after 1466 iteration = [[0.24480405]]
# Cost after 1467 iteration = [[0.24472276]]
# Cost after 1468 iteration = [[0.24464155]]
# Cost after 1469 iteration = [[0.24456043]]
# Cost after 1470 iteration = [[0.24447939]]
# Cost after 1471 iteration = [[0.24439844]]
# Cost after 1472 iteration = [[0.24431757]]
# Cost after 1473 iteration = [[0.24423678]]
# Cost after 1474 iteration = [[0.24415608]]
# Cost after 1475 iteration = [[0.24407546]]
# Cost after 1476 iteration = [[0.24399493]]
# Cost after 1477 iteration = [[0.24391447]]
# Cost after 1478 iteration = [[0.2438341]]
# Cost after 1479 iteration = [[0.24375382]]
# Cost after 1480 iteration = [[0.24367361]]
# Cost after 1481 iteration = [[0.24359349]]
# Cost after 1482 iteration = [[0.24351345]]
# Cost after 1483 iteration = [[0.2434335]]
# Cost after 1484 iteration = [[0.24335362]]
# Cost after 1485 iteration = [[0.24327383]]
# Cost after 1486 iteration = [[0.24319412]]
# Cost after 1487 iteration = [[0.24311449]]
# Cost after 1488 iteration = [[0.24303494]]
# Cost after 1489 iteration = [[0.24295548]]
# Cost after 1490 iteration = [[0.24287609]]
# Cost after 1491 iteration = [[0.24279679]]
# Cost after 1492 iteration = [[0.24271757]]
# Cost after 1493 iteration = [[0.24263843]]
# Cost after 1494 iteration = [[0.24255937]]
# Cost after 1495 iteration = [[0.24248039]]
# Cost after 1496 iteration = [[0.2424015]]
# Cost after 1497 iteration = [[0.24232268]]
# Cost after 1498 iteration = [[0.24224394]]
# Cost after 1499 iteration = [[0.24216529]]
# The cost after training is 0.24216529.
# The resulting vector of weights is [7e-08, 0.0005239, -0.00055517]

# %% [markdown]
# **Expected Output**:
#
# ```
# The cost after training is 0.24216529.
# The resulting vector of weights is [7e-08, 0.0005239, -0.00055517]
# ```

# %% [markdown]
# # Part 4: Test your logistic regression
#
# It is time for you to test your logistic regression function on some new input that your model has not seen before.
#
# #### Instructions: Write `predict_tweet`
# Predict whether a tweet is positive or negative.
#
# * Given a tweet, process it, then extract the features.
# * Apply the model's learned weights on the features to get the logits.
# * Apply the sigmoid to the logits to get the prediction (a value between 0 and 1).
#
# $$y_{pred} = sigmoid(\mathbf{x} \cdot \theta)$$

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def predict_tweet(tweet, freqs, theta):
    '''
    Input: 
        tweet: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output: 
        y_pred: the probability of a tweet being positive or negative
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # extract the features of the tweet and store it into x
    x = extract_features(tweet, freqs)
    
    # make the prediction using x and theta
    y_pred = sigmoid(np.dot(x, theta))
    
    ### END CODE HERE ###
    
    return y_pred

# %%
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
# Out:
# I am happy -> 0.518580
# I am bad -> 0.494339
# this movie should have been great. -> 0.515331
# great -> 0.515464
# great great -> 0.530898
# great great great -> 0.546273
# great great great great -> 0.561561

# %% [markdown]
# **Expected Output**:
# ```
# I am happy -> 0.518580
# I am bad -> 0.494339
# this movie should have been great. -> 0.515331
# great -> 0.515464
# great great -> 0.530898
# great great great -> 0.546273
# great great great great -> 0.561561
# ```

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'My friend is a good who  never helps me a lot :)'
predict_tweet(my_tweet, freqs, theta)
# Out:
# array([[0.82757164]])

# %% [markdown]
# ## Check performance using the test set
# After training your model using the training set above, check how your model might perform on real, unseen data, by testing it against the test set.
#
# #### Instructions: Implement `test_logistic_regression`
# * Given the test data and the weights of your trained model, calculate the accuracy of your logistic regression model.
# * Use your `predict_tweet()` function to make predictions on each tweet in the test set.
# * If the prediction is > 0.5, set the model's classification `y_hat` to 1, otherwise set the model's classification `y_hat` to 0.
# * A prediction is accurate when `y_hat` equals `test_y`.  Sum up all the instances when they are equal and divide by `m`.

# %%
a = [1, 2, 4, 5]
np.array(a).reshape(len(a), 1).shape
# Out:
# (4, 1)

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use np.asarray() to convert a list to a numpy array</li>
#     <li>Use np.squeeze() to make an (m,1) dimensional array into an (m,) array </li>
# </ul>
# </p>

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def test_logistic_regression(test_x, test_y, freqs, theta):
    """
    Input: 
        test_x: a list of tweets
        test_y: (m, 1) vector with the corresponding labels for the list of tweets
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output: 
        accuracy: (# of tweets classified correctly) / (total # of tweets)
    """
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # the list for storing predictions
    y_hat = []
    
    for tweet in test_x:
        # get the label prediction for the tweet
        y_pred = predict_tweet(tweet, freqs, theta)
        
        if y_pred > 0.5:
            # append 1.0 to the list
            y_hat.append(1.0)
        else:
            # append 0 to the list
            y_hat.append(0.0)

    # With the above implementation, y_hat is a list, but test_y is (m,1) array
    # convert both to one-dimensional arrays in order to compare them using the '==' operator
    accuracy = (np.array(y_hat).reshape(len(y_hat), 1) == test_y).mean()

    ### END CODE HERE ###
    
    return accuracy

# %%
tmp_accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmp_accuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.9950

# %% [markdown]
# #### Expected Output:
# ```0.9950```
# Pretty good!

# %% [markdown]
# # Part 5: Error Analysis
#
# In this part you will see some tweets that your model misclassified. Why do you think the misclassifications happened? Specifically what kind of tweets does your model misclassify?

# %%
# Some error analysis done for you
print('Label Predicted Tweet')
for x,y in zip(test_x,test_y):
    y_hat = predict_tweet(x, freqs, theta)

    if np.abs(y - (y_hat > 0.5)) > 0:
        print('THE TWEET IS:', x)
        print('THE PROCESSED TWEET IS:', process_tweet(x))
        print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Label Predicted Tweet
# THE TWEET IS: @jaredNOTsubway @iluvmariah @Bravotv Then that truly is a LATERAL move! Now, we all know the Queen Bee is UPWARD BOUND : ) #MovingOnUp
# THE PROCESSED TWEET IS: ['truli', 'later', 'move', 'know', 'queen', 'bee', 'upward', 'bound', 'movingonup']
# 1	0.49996890	b'truli later move know queen bee upward bound movingonup'
# THE TWEET IS: @MarkBreech Not sure it would be good thing 4 my bottom daring 2 say 2 Miss B but Im gonna be so stubborn on mouth soaping ! #NotHavingit :p
# THE PROCESSED TWEET IS: ['sure', 'would', 'good', 'thing', '4', 'bottom', 'dare', '2', 'say', '2', 'miss', 'b', 'im', 'gonna', 'stubborn', 'mouth', 'soap', 'nothavingit', ':p']
# 1	0.48622857	b'sure would good thing 4 bottom dare 2 say 2 miss b im gonna stubborn mouth soap nothavingit :p'
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots
# http://t.co/UGQzOx0huu
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48370665	b"i'm play brain dot braindot"
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/aOKldo3GMj http://t.co/xWCM9qyRG5
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48370665	b"i'm play brain dot braindot"
# THE TWEET IS: I'm playing Brain Dots : ) #BrainDots http://t.co/R2JBO8iNww http://t.co/ow5BBwdEMY
# THE PROCESSED TWEET IS: ["i'm", 'play', 'brain', 'dot', 'braindot']
# 1	0.48370665	b"i'm play brain dot braindot"
# THE TWEET IS: off to the park to get some sunlight : )
# THE PROCESSED TWEET IS: ['park', 'get', 'sunlight']
# 1	0.49578765	b'park get sunlight'
# THE TWEET IS: @msarosh Uff Itna Miss karhy thy ap :p
# THE PROCESSED TWEET IS: ['uff', 'itna', 'miss', 'karhi', 'thi', 'ap', ':p']
# 1	0.48199810	b'uff itna miss karhi thi ap :p'
# THE TWEET IS: @phenomyoutube u probs had more fun with david than me : (
# THE PROCESSED TWEET IS: ['u', 'prob', 'fun', 'david']
# 0	0.50020353	b'u prob fun david'
# THE TWEET IS: pats jay : (
# THE PROCESSED TWEET IS: ['pat', 'jay']
# 0	0.50039294	b'pat jay'
# THE TWEET IS: my beloved grandmother : ( https://t.co/wt4oXq5xCf
# THE PROCESSED TWEET IS: ['belov', 'grandmoth']
# 0	0.50000002	b'belov grandmoth'

# %% [markdown]
# Later in this specialization, we will see how we can use deep learning to improve the prediction performance.

# %% [markdown]
# # Part 6: Predict with your own tweet

# %%
# Feel free to change the tweet below
my_tweet = 'This is a ridiculously bright movie. The plot was terrible and I was sad until the ending!'
print(process_tweet(my_tweet))
y_hat = predict_tweet(my_tweet, freqs, theta)
print(y_hat)
if y_hat > 0.5:
    print('Positive sentiment')
else: 
    print('Negative sentiment')
# Out:
# ['ridicul', 'bright', 'movi', 'plot', 'terribl', 'sad', 'end']
# [[0.48139087]]
# Negative sentiment
